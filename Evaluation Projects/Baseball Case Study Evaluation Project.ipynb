# %% [markdown]
# Importing Important Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the Dataset

# %%
df=pd.read_csv('baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# ### Description of the variables:
# 1. W: Wins
# 2. R: Runs scored
# 3. AB: At bat
# 4. H: Base Hit
# 5. 2B: Double
# 6. 3B: Triple
# 7. HR: Home runs
# 8. BB: Base on balls
# 9. SO: Strikeout
# 10. SB: Stolen base
# 11. RA: Run Average
# 12. ER: Earned run
# 13. ERA: Earned Run Average
# 14. CG: Complete Game
# 15. SHO: Shutout
# 16. SV: Save
# 17. E: Errors

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# The dataset contains 30 rows and 17 columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# We have 16 int64 type data and 1 float64 type data in the dataset. So all the columns are numerical.

# %%
#checking the nunique values in all columns
df.nunique()
# Out:
# W      24
# R      28
# AB     29
# H      29
# 2B     22
# 3B     23
# HR     27
# BB     29
# SO     29
# SB     27
# RA     30
# ER     30
# ERA    30
# CG      9
# SHO    12
# SV     20
# E      21
# dtype: int64

# %% [markdown]
# We can see the number of unique values present in each column.

# %%
#checking for null values through heatmap and info function
df.info()

sns.heatmap(df.isnull())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# As you can see above, there are no null values present in our data.

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# Observations:
# 1. The Mean and Median (50%) are same for all the columns.
# 2. There is not more difference between the 75% and max in all the columns. There might be very less outliers present in all the columns.

# %% [markdown]
# ## Data Visualization

# %%
sns.regplot(x='R',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='R', ylabel='W'>

# %% [markdown]
# We can see positive relationship between the Runs scored and Wins. The more the runs the better the chances of winning.

# %%
sns.regplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %% [markdown]
# Here also we can see that the more the home runs the better chances of winning.

# %%
sns.regplot(x='SO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='W'>

# %% [markdown]
# Here also we can see the more the Stirke outs the better chances of winning.

# %%
sns.regplot(x='CG',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='W'>

# %% [markdown]
# Here also we can see that the more the complete games the better chances of winning.

# %%
sns.regplot(x='ER',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='W'>

# %% [markdown]
# As we can see above there is negative relation between the earned runs and Wins.

# %%
sns.regplot(x='SHO',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='W'>

# %% [markdown]
# As we can see here the Wins and Shutouts are positively related to each other.

# %%
sns.regplot(x='SV',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='W'>

# %% [markdown]
# Here we can see the more the saves the better chances of winning.

# %%
sns.regplot(x='E',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='E', ylabel='W'>

# %% [markdown]
# Here we can see the less the errors the more the chances of winning.

# %%
sns.pairplot(df)

# %% [markdown]
# #### Checking For outliers

# %%
plt.figure(figsize=(20,20))
for i in enumerate(df.columns):
    plt.subplot(5,4,i[0]+1)
    sns.boxplot(df[i[1]])

# %% [markdown]
# As we can see above we have very less outliers present in R(Runs), ERA(Earned Runs Average), SHO(Shutout), SV(Save) and E(Errors).

# %% [markdown]
# #### Removing Outliers

# %% [markdown]
# Zscore method

# %%
#Splitting the data to remove outliers
x= df.drop(['W'], axis=1)
y= df['W']
x.shape
# Out:
# (30, 16)

# %%
y.shape
# Out:
# (30,)

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193  0.787299  1.534902
# 1   0.134432  0.711094  0.970681  0.127403  1.235809  0.243967  0.536592
# 2   0.332906  1.115233  0.151891  1.588795  0.223808  0.723377  1.139144
# 3   1.146419  0.241522  0.401088  0.828122  0.418423  0.883181  1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347  0.403770  0.251360
# 5   3.509647  0.104884  1.361089  1.869832  1.391501  2.185047  1.798742
# 6   1.311430  0.732263  0.116292  0.153633  1.196885  1.545833  1.513510
# 7   0.428681  0.451289  0.596886  1.615025  1.099578  1.705636  0.910958
# 8   0.765626  0.451289  0.365489  0.183611  0.068115  0.107601  0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423  0.084163  0.158660
# 10  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125  0.301276
# 12  0.471376  1.432772  1.291077  1.783647  1.002270  0.395247  0.607900
# 13  0.557920  0.400291  0.436688  0.715707  0.904962  1.098383  0.158660
# 14  0.099814  1.208570  0.026106  0.127403  1.430424  0.563574  0.105179
# 15  0.713699  0.465723  0.312089  0.745685  0.749270  0.851220  0.657815
# 16  0.151740  1.656011  1.040693  0.970514  0.418423  0.755338  0.144398
# 17  0.013270  0.364688  1.113079  0.153633  0.126500  0.235444  1.745261
# 18  0.575229  0.523457  0.454487  0.041219  0.262731  0.595534  1.017920
# 19  0.834861  0.789997  0.383288  0.996744  0.418423  0.107601  0.479546
# 20  0.090583  0.154920  0.935081  1.139136  1.391501  0.427208  0.336930
# 21  0.255593  1.274002  0.721484  0.547085  1.780732  0.427208  1.246105
# 22  1.302198  0.768828  0.293103  2.177099  0.846578  1.394552  1.677518
# 23  1.994550  1.389471  0.757084  1.333988  1.294193  2.033766  0.033871
# 24  1.077184  0.183787  0.525687  0.153633  0.554654  1.074945  1.463595
# 25  0.367523  1.894646  1.024080  0.659500  0.515731  0.746815  1.673953
# 26  0.134432  0.703396  1.467888  0.745685  0.749270  0.883181  0.215706
# 27  0.549843  1.915815  1.610286  0.801892  1.625040  0.307888  0.372584
# 28  0.661773  0.855429  1.415675  0.828122  0.457346  0.499652  0.768343
# 29  0.844092  0.804431  1.343289  0.041219  1.722347  0.714854  1.445768
#
#           SO        SB        RA        ER       ERA        CG       SHO  \
# 0   2.697630  0.913883  0.666234  0.505110  0.506955  0.539806  0.814629
# 1   0.154878  0.601826  0.165971  0.248930  0.254598  0.539806  0.172800
# 2   0.893982  0.111449  0.680339  0.751623  0.641347  2.772641  0.320914
# 3   0.168602  0.690985  0.180076  0.103922  0.053010  1.300442  0.567771
# 4   0.105866  0.022290  1.618803  1.597501  1.531318  1.300442  0.172800
# 5   0.952796  0.200609  0.257184  0.389104  0.350165  1.300442  0.320914
# 6   0.207812  0.913883  0.137760  0.234429  0.165003  0.171757  1.802057
# 7   0.811641  1.760897  0.067235  0.147424  0.209800  1.275906  0.320914
# 8   0.605790  0.156029  0.652129  0.461608  0.484557  0.907856  0.172800
# 9   0.982204  0.557246  0.913544  0.843461  0.792164  0.171757  0.320914
# 10  0.148997  0.780144  0.631441  0.640451  0.635374  0.564343  0.567771
# 11  1.409590  1.671738  0.990653  0.925632  0.865333  0.564343  0.419657
# 12  0.962599  1.404260  0.186658  0.084588  0.036584  0.539806  0.172800
# 13  0.860654  0.646405  0.532705  0.596948  0.456185  0.932393  0.172800
# 14  1.266474  0.245188  0.575021  0.408438  0.411388  0.564343  0.913371
# 15  0.184286  0.646405  2.302433  2.288705  2.276445  0.907856  0.913371
# 16  0.723420  0.646405  1.300966  1.505663  1.671683  1.275906  0.419657
# 17  2.644696  0.512666  1.131704  1.302652  1.335704  0.932393  2.394514
# 18  0.497964  0.022290  0.687862  0.669452  0.724968  0.907856  1.061486
# 19  0.066657  2.251273  0.927650  0.930466  0.836961  0.539806  0.814629
# 20  0.409742  1.448839  1.061179  1.143144  1.178913  0.907856  0.666514
# 21  0.939073  1.181361  0.750865  0.853129  0.753340  0.196293  0.419657
# 22  0.962599  1.270521  0.144343  0.031418  0.142604  1.275906  0.172800
# 23  1.384104  0.646405  1.012281  0.901464  1.016150  0.171757  0.320914
# 24  0.252903  0.200609  1.703434  1.641004  1.643311  0.907856  1.061486
# 25  0.096064  1.092202  1.315071  1.201147  1.156515  0.932393  2.394514
# 26  0.874377  0.423507  0.863706  0.563113  0.529354  1.300442  1.653943
# 27  0.625395  2.162114  0.349338  0.335934  0.187402  0.907856  0.172800
# 28  0.772432  0.066870  0.603231  0.277931  0.299395  0.907856  1.308343
# 29  0.341125  0.601826  2.197114  2.366042  2.427263  0.196293  1.802057
#
#           SV         E
# 0   1.671607  0.461470
# 1   0.249879  0.607197
# 2   0.654856  1.117242
# 3   0.784104  0.485758
# 4   1.042600  0.607197
# 5   1.171848  0.461470
# 6   0.637623  0.097152
# 7   0.008617  1.262970
# 8   2.188598  0.048576
# 9   0.396360  0.194303
# 10  0.249879  1.797303
# 11  0.525608  0.680061
# 12  0.379127  0.097152
# 13  0.249879  0.024288
# 14  1.947335  2.307348
# 15  2.447094  0.121439
# 16  1.413111  2.015894
# 17  0.637623  1.214394
# 18  0.396360  1.578712
# 19  1.042600  0.315742
# 20  0.896119  0.461470
# 21  0.267112  0.315742
# 22  1.042600  1.262970
# 23  0.120631  0.315742
# 24  1.042600  1.651576
# 25  0.508375  1.408697
# 26  0.267112  1.190106
# 27  0.120631  0.607197
# 28  0.267112  0.170015
# 29  0.913352  0.048576

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
z.iloc[5][0]
# Out:
# 3.5096470447193067

# %%
df1=df[(z<3).all(axis=1)]
print(df.shape)
print(df1.shape)
# Out:
# (30, 17)
# (29, 17)

# %%
# Data loss percentage using zscore method
a=((30-29)/30)*100
a
# Out:
# 3.3333333333333335

# %% [markdown]
# IQR Method

# %%
Q1 = x.quantile(0.25)
Q3 = x.quantile(0.75)
IQR=Q3-Q1
df2=x[~((x < (Q1 - 1.5 * IQR)) | (x > (Q3 + 1.5 * IQR))).any(axis=1)]
df2.shape
# Out:
# (20, 16)

# %%
# Data loss percentage using IQR method
b=((30-20)/30)*100
b
# Out:
# 33.33333333333333

# %% [markdown]
# The Data loss percentage is 3.33% using zscore and 33.33% using IQR. Only 10% of data loss is acceptable. Hence i am selecting zscore method.

# %%
df=df1
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (29, 17)

# %% [markdown]
# #### Checking for skewness

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
plt.figure(figsize=(20,20))
for i in enumerate(df):
    plt.subplot(5,4,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()

# %% [markdown]
# Here we can see that a little skewness is present in  H, CG, SHO, SV and E.

# %%
print('Before removing skewness')
skewed=['H','CG','SHO','SV','E']
plt.figure(figsize=(10,10))
for i in enumerate(skewed):
    plt.subplot(3,2,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# Before removing skewness

# %% [markdown]
# #### Removing skewness

# %%
# using power transform method
from sklearn.preprocessing import power_transform
df[['CG','SHO','SV','E']]=power_transform(df[['CG','SHO','SV','E']],method='yeo-johnson')
df['H']=np.log(df['H'])
# using log transform on column H as the power transform transforms the H column to 0

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738423
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %%
print('After removing skewness')
plt.figure(figsize=(10,10))
for i in enumerate(skewed):
    plt.subplot(3,2,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# After removing skewness

# %% [markdown]
# Here we can see that the skewness is removed.

# %% [markdown]
# ## Correlation between variables

# %%
dfcor=df.corr()
dfcor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.390451 -0.085780 -0.020787  0.384886 -0.206737  0.245697
# R    0.390451  1.000000  0.438022  0.432235  0.469293  0.134204  0.586894
# AB  -0.085780  0.438022  1.000000  0.770155  0.490752  0.445604 -0.064653
# H   -0.020787  0.432235  0.770155  1.000000  0.527354  0.579733 -0.219201
# 2B   0.384886  0.469293  0.490752  0.527354  1.000000  0.342419 -0.098695
# 3B  -0.206737  0.134204  0.445604  0.579733  0.342419  1.000000 -0.369299
# HR   0.245697  0.586894 -0.064653 -0.219201 -0.098695 -0.369299  1.000000
# BB   0.447513  0.258450 -0.137850 -0.221773  0.211243 -0.404852  0.336814
# SO   0.156469  0.081158 -0.111243 -0.373302 -0.096772 -0.196586  0.479914
# SB  -0.169503  0.075323  0.373674  0.420201  0.194308  0.483818 -0.166072
# RA  -0.823176 -0.013858  0.315499  0.243639 -0.215196  0.312750 -0.092586
# ER  -0.815308  0.007727  0.309146  0.279955 -0.224993  0.333731 -0.062094
# ERA -0.826952 -0.009122  0.254872  0.255885 -0.248212  0.325883 -0.070756
# CG   0.007696  0.155122 -0.059648  0.071667  0.227220 -0.004496  0.118284
# SHO  0.481626 -0.113640 -0.194219 -0.129966  0.088226 -0.066384 -0.024448
# SV   0.756713  0.083261 -0.147964 -0.103112  0.241326 -0.269255  0.106523
# E   -0.079633  0.039865  0.332002 -0.020046  0.152541  0.080498 -0.165883
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.447513  0.156469 -0.169503 -0.823176 -0.815308 -0.826952  0.007696
# R    0.258450  0.081158  0.075323 -0.013858  0.007727 -0.009122  0.155122
# AB  -0.137850 -0.111243  0.373674  0.315499  0.309146  0.254872 -0.059648
# H   -0.221773 -0.373302  0.420201  0.243639  0.279955  0.255885  0.071667
# 2B   0.211243 -0.096772  0.194308 -0.215196 -0.224993 -0.248212  0.227220
# 3B  -0.404852 -0.196586  0.483818  0.312750  0.333731  0.325883 -0.004496
# HR   0.336814  0.479914 -0.166072 -0.092586 -0.062094 -0.070756  0.118284
# BB   1.000000  0.315566 -0.117622 -0.425381 -0.455832 -0.465794  0.445335
# SO   0.315566  1.000000  0.038188 -0.140570 -0.177655 -0.195362 -0.063129
# SB  -0.117622  0.038188  1.000000  0.134315  0.146243  0.128848 -0.040524
# RA  -0.425381 -0.140570  0.134315  1.000000  0.991286  0.986781  0.062434
# ER  -0.455832 -0.177655  0.146243  0.991286  1.000000  0.997261  0.067069
# ERA -0.465794 -0.195362  0.128848  0.986781  0.997261  1.000000  0.073959
# CG   0.445335 -0.063129 -0.040524  0.062434  0.067069  0.073959  1.000000
# SHO  0.441043  0.204704 -0.100054 -0.642749 -0.640161 -0.640503  0.208515
# SV   0.207948  0.125572 -0.195772 -0.625996 -0.604541 -0.619790 -0.302413
# E   -0.056106  0.164817  0.070527  0.231036  0.165556  0.138692 -0.070484
#
#           SHO        SV         E
# W    0.481626  0.756713 -0.079633
# R   -0.113640  0.083261  0.039865
# AB  -0.194219 -0.147964  0.332002
# H   -0.129966 -0.103112 -0.020046
# 2B   0.088226  0.241326  0.152541
# 3B  -0.066384 -0.269255  0.080498
# HR  -0.024448  0.106523 -0.165883
# BB   0.441043  0.207948 -0.056106
# SO   0.204704  0.125572  0.164817
# SB  -0.100054 -0.195772  0.070527
# RA  -0.642749 -0.625996  0.231036
# ER  -0.640161 -0.604541  0.165556
# ERA -0.640503 -0.619790  0.138692
# CG   0.208515 -0.302413 -0.070484
# SHO  1.000000  0.196672 -0.206739
# SV   0.196672  1.000000 -0.032529
# E   -0.206739 -0.032529  1.000000

# %%
plt.figure(figsize=(14,14))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
# 1. The columns RA(Run Avergae), ER(Earned Run) and ERA(Earned Run Average) are highly negative correlated to our target variable W(Win).
# 2. The SV(Save) is highly positve correlated to W(Win).
# 3. The SHO(Shutout), BB(Base on Balls), 2B(doubles) and R(Runs) are moderately positive correlated to W(Win).
# 4. The SV(Save) and SHO(Shutout) are negatively correlated to RA(Run Avergae), ER(Earned Run) and ERA(Earned Run Average).

# %% [markdown]
# # Checking Multicolinearity

# %%
#Splitting the data
x= df.drop(['W'], axis=1)
y= df['W']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["faetures"]=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#        VIF Factor faetures
# 0     1119.709877        R
# 1   120981.654421       AB
# 2   105314.673526        H
# 3      900.294457       2B
# 4       34.706508       3B
# 5      202.223659       HR
# 6      237.256181       BB
# 7      425.031442       SO
# 8       26.385463       SB
# 9    17046.029321       RA
# 10  166537.605039       ER
# 11  123006.385375      ERA
# 12       2.860666       CG
# 13       3.210886      SHO
# 14       5.913642       SV
# 15       2.029498        E

# %% [markdown]
# ER (Earned Run) has the highest VIF value hence we can remove it from out dataset.

# %%
df.drop('ER', axis=1, inplace=True)
df.head()
# Out:
#     W    R    AB         H   2B  3B   HR   BB    SO   SB   RA   ERA        CG  \
# 0  95  724  5575  7.311218  300  42  139  383   973  104  641  3.73 -0.307098
# 1  83  696  5467  7.207119  277  44  156  439  1264   70  700  4.07 -0.307098
# 2  81  669  5439  7.240650  303  29  141  533  1157   86  640  3.67  2.011315
# 3  76  622  5533  7.230563  260  27  136  404  1231   68  701  3.98  1.264463
# 4  74  689  5605  7.323171  289  49  151  455  1259   83  803  4.64  1.264463
#
#         SHO        SV         E
# 0 -0.787002  1.532753 -0.348265
# 1  0.236737  0.312020 -0.540820
# 2 -0.252844 -0.664137 -1.326125
# 3 -0.513555 -0.820689  0.650818
# 4  0.236737 -1.149165 -0.540820

# %%
#Splitting the data
x= df.drop(['W'], axis=1)
y= df['W']

# %%
vif_calc()
# Out:
#       VIF Factor faetures
# 0    1000.205935        R
# 1   34109.679540       AB
# 2   29877.257066        H
# 3     835.000374       2B
# 4      33.848401       3B
# 5     181.057834       HR
# 6     236.931257       BB
# 7     420.802276       SO
# 8      22.886231       SB
# 9   12602.365710       RA
# 10  10218.721785      ERA
# 11      2.403271       CG
# 12      3.021796      SHO
# 13      2.449799       SV
# 14      1.876919        E

# %% [markdown]
# The VIF value of AB is also quite high we can remove that as well.

# %%
df.drop('AB', axis=1, inplace=True)
df.head()
# Out:
#     W    R         H   2B  3B   HR   BB    SO   SB   RA   ERA        CG  \
# 0  95  724  7.311218  300  42  139  383   973  104  641  3.73 -0.307098
# 1  83  696  7.207119  277  44  156  439  1264   70  700  4.07 -0.307098
# 2  81  669  7.240650  303  29  141  533  1157   86  640  3.67  2.011315
# 3  76  622  7.230563  260  27  136  404  1231   68  701  3.98  1.264463
# 4  74  689  7.323171  289  49  151  455  1259   83  803  4.64  1.264463
#
#         SHO        SV         E
# 0 -0.787002  1.532753 -0.348265
# 1  0.236737  0.312020 -0.540820
# 2 -0.252844 -0.664137 -1.326125
# 3 -0.513555 -0.820689  0.650818
# 4  0.236737 -1.149165 -0.540820

# %%
#Splitting the data
x= df.drop(['W'], axis=1)
y= df['W']

# %%
vif_calc()
# Out:
#      VIF Factor faetures
# 0    992.862758        R
# 1   1553.452426        H
# 2    777.978336       2B
# 3     33.659839       3B
# 4    163.423148       HR
# 5    230.777594       BB
# 6    369.796113       SO
# 7     21.270487       SB
# 8   8497.467069       RA
# 9   7289.367251      ERA
# 10     2.263930       CG
# 11     2.836023      SHO
# 12     2.446247       SV
# 13     1.805881        E

# %% [markdown]
# As we can see the VIF values for other columns has also reduced. By dropping ER and AB we have lost 12.5% data. We do not have lose more data. Hence not dropping other columns.

# %% [markdown]
# # Feature Scaling using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x
# Out:
#            R         H        2B        3B        HR        BB        SO  \
# 0   0.959398  1.723715  1.556538  1.010845 -0.765863 -1.536359 -2.727623
# 1   0.331147 -0.949854  0.201171  1.208917 -0.181389 -0.495021  0.121896
# 2  -0.274666 -0.088687  1.733325 -0.276617 -0.697101  1.252941 -0.925866
# 3  -1.329231 -0.347738 -0.800621 -0.474688 -0.869006 -1.145857 -0.201246
# 4   0.174084  2.030685  0.908319  1.704094 -0.353293 -0.197495  0.072935
# 5   1.856900 -0.051892 -0.093474 -1.266972  1.743939  1.643442 -0.240414
# 6   0.712585 -0.553127 -1.625627 -1.167936  1.915843 -0.885522  0.777970
# 7  -0.835605 -0.310570  0.260100  0.020490  0.196801 -0.550807  0.572335
# 8   1.497899  1.689380  1.202964  0.119526 -0.009484  0.230197 -1.013995
# 9   1.565212  0.349410  0.319029  0.020490  0.368705  0.695081 -0.181661
# 10  1.071586 -0.684689  0.260100 -0.573723  2.362794  0.378960  1.375292
# 11 -0.454167 -1.294852 -1.802414 -1.068901  0.506228 -0.569402 -0.994411
# 12 -0.566355 -0.384960 -0.682763 -0.969865  1.262607  0.230197  0.826931
# 13  0.286272  0.094762  0.201171  1.406988 -0.525197  0.174411 -1.297968
# 14 -0.768292 -0.254920  0.849390  0.713739 -0.834625  0.750867  0.151272
# 15  0.353585  1.116118  1.085106 -0.474688 -0.731482 -0.085923  0.689841
# 16  0.174084 -1.102614 -0.093474 -0.177581  0.334324  1.885182  2.609104
# 17 -0.588792 -0.403591  0.024384  0.218561 -0.559578 -0.997094  0.464621
# 18 -0.925355 -0.329148 -0.977408 -0.474688  0.196801  0.564913  0.033766
# 19  0.039459 -0.911805  1.261893 -1.465043  0.540609  0.416151  0.376492
# 20  0.488210 -0.684689 -0.505976 -1.861185  0.540609  1.364512  0.905268
# 21 -1.531169  0.367503 -2.214917  0.812774 -1.419099 -1.685122 -0.994411
# 22 -2.428670 -0.722403 -1.330982 -1.366007 -2.106716  0.100030 -1.415474
# 23 -1.239481 -0.478250 -0.093474  0.515668 -1.075291 -1.461978  0.219817
# 24 -0.319542 -1.007033 -0.623834 -0.573723  0.884418  1.810800  0.063143
# 25  0.331147  1.534301  0.849390  0.713739 -0.869006 -0.160305 -0.906281
# 26  0.869648  1.672195  0.908319  1.605059 -0.250150  0.453341  0.591919
# 27 -0.700980 -1.430280 -0.800621  0.416632 -0.456435 -0.736760  0.738802
# 28  1.251086  1.413032  0.024384  1.704094  0.850037 -1.443382  0.307947
#
#           SB        RA       ERA        CG       SHO        SV         E
# 0   0.905953 -0.664514 -0.511388 -0.307098 -0.787002  1.532753 -0.348265
# 1  -0.585315  0.154638  0.238952 -0.307098  0.236737  0.312020 -0.540820
# 2   0.116458 -0.678397 -0.643801  2.011315 -0.252844 -0.664137 -1.326125
# 3  -0.673037  0.168522  0.040333  1.264463 -0.513555 -0.820689  0.650818
# 4  -0.015124  1.584683  1.496876  1.264463  0.236737 -1.149165 -0.540820
# 5  -0.892341  0.126870  0.150677  0.121871 -2.064039  0.677176  0.082858
# 6  -1.725697  0.057451  0.194815 -1.732896 -0.252844  0.052325 -1.588197
# 7   0.160319 -0.650630 -0.489319 -0.870682  0.236737  1.908137  0.237592
# 8  -0.541454  0.890486  0.768604  0.121871 -0.252844 -0.365006  0.383386
# 9   0.774370  0.612808  0.614123  0.770649 -0.513555  0.312020  1.554265
# 10  1.651587 -0.983844 -0.864490  0.770649  0.468029 -0.512328 -0.641926
# 11 -1.374810 -0.192460 -0.047943 -0.307098  0.236737  0.436838  0.082858
# 12 -0.629176  0.515620  0.437572  1.031663  0.236737  0.312020  0.161388
# 13 -0.234429  0.557272  0.393434  0.770649  0.908147 -2.498840  1.810553
# 14 -0.629176 -2.275049 -2.254827 -0.870682  0.908147  2.084917  0.311562
# 15  0.642788 -1.289290 -1.658968 -1.732896  0.468029  1.333006  1.669209
# 16  0.511205 -1.122683 -1.327935  1.031663  2.090856  0.677176  1.203715
# 17  0.028736  0.668344  0.702398 -0.870682 -1.075340 -0.365006  1.430810
# 18  2.221778  0.904370  0.812742 -0.307098 -0.787002 -1.149165 -0.167685
# 19 -1.418671 -1.053264 -1.173453 -0.870682  0.691583  0.906024 -0.348265
# 20 -1.155506 -0.747817 -0.754146  0.472300  0.468029 -0.221934 -0.167685
# 21  1.256840 -0.150808  0.128608 -1.732896  0.236737 -1.149165 -1.588197
# 22 -0.629176  0.987674  0.989293  0.121871 -0.252844  0.183904 -0.167685
# 23  0.204180  1.667986  1.607220 -0.870682 -1.075340 -1.149165  1.472959
# 24 -1.067784 -1.303174 -1.151385  1.031663  2.090856  0.558509 -1.870191
# 25  0.423484 -0.858889 -0.533457  1.264463  1.521828 -0.221934 -1.454792
# 26  2.134056  0.335129  0.172746 -0.870682  0.236737  0.183904 -0.540820
# 27 -0.058985  0.585040  0.283090 -0.870682 -1.381412 -0.221934  0.001905
# 28  0.598927  2.153924  2.379630  0.472300 -2.064039 -0.982264  0.237592

# %% [markdown]
# # Modelling

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# Creating train test split and finding the best random_state

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    RF = RandomForestRegressor()
    RF.fit(x_train,y_train)
    pred=RF.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Maximum r2 score is  ",maxAccu," At random state ",maxRS)
# Out:
# Maximum r2 score is   0.8602765666540068  At random state  143

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# #### 1. Linear Regression

# %%
LRR = LinearRegression()
LRR.fit(x_train,y_train)
predLRR=LRR.predict(x_test)
pred_train=LRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predLRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predLRR))
print('Mean squared error: ',mean_squared_error(y_test, predLRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predLRR)))
# Out:
# R2 Score:  0.786162120993308
# R2 score on training data:  95.84595057093232
# Mean absolute error:  2.785070481202124
# Mean squared error:  15.639864872906111
# Root Mean squared error:  3.954726902442963

# %% [markdown]
# #### 2. Decision Tree Regressor

# %%
print('DTR for squared_error')
DTR1 = DecisionTreeRegressor(criterion='squared_error')
DTR1.fit(x_train,y_train)
predDTR1=DTR1.predict(x_test)
pred_train=DTR1.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR1))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR1))
print('Mean squared error: ',mean_squared_error(y_test, predDTR1))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR1)))
print('\n')

print('DTR for friedman_mse')
DTR2 = DecisionTreeRegressor(criterion='friedman_mse')
DTR2.fit(x_train,y_train)
predDTR2=DTR2.predict(x_test)
pred_train=DTR2.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR2))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR2))
print('Mean squared error: ',mean_squared_error(y_test, predDTR2))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR2)))
print('\n')

print('DTR for absolute_error')
DTR3 = DecisionTreeRegressor(criterion='absolute_error')
DTR3.fit(x_train,y_train)
predDTR3=DTR3.predict(x_test)
pred_train=DTR3.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR3))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR3))
print('Mean squared error: ',mean_squared_error(y_test, predDTR3))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR3)))
print('\n')

print('DTR for poisson')
DTR4 = DecisionTreeRegressor(criterion='poisson')
DTR4.fit(x_train,y_train)
predDTR4=DTR4.predict(x_test)
pred_train=DTR4.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR4))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR4))
print('Mean squared error: ',mean_squared_error(y_test, predDTR4))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR4)))
# Out:
# DTR for squared_error
# R2 Score:  0.5829851879984809
# R2 score on training data:  100.0
# Mean absolute error:  4.5
# Mean squared error:  30.5
# Root Mean squared error:  5.522680508593631
#
#
# DTR for friedman_mse
# R2 Score:  0.2913026965438663
# R2 score on training data:  100.0
# Mean absolute error:  6.5
# Mean squared error:  51.833333333333336
# Root Mean squared error:  7.199537022151725
#
#
# DTR for absolute_error
# R2 Score:  -0.4379035320926701
# R2 score on training data:  100.0
# Mean absolute error:  9.166666666666666
# Mean squared error:  105.16666666666667
# Root Mean squared error:  10.25508004194344
#
#
# DTR for poisson
# R2 Score:  0.20470945689327757
# R2 score on training data:  100.0
# Mean absolute error:  7.166666666666667
# Mean squared error:  58.166666666666664
# Root Mean squared error:  7.626707459098367

# %% [markdown]
# We can see that Decision Tree Regressor is working well for friedman_mse criterion

# %%
DTR = DecisionTreeRegressor(criterion='friedman_mse')
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR))
print('Mean squared error: ',mean_squared_error(y_test, predDTR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR)))
# Out:
# R2 Score:  0.4394227117356627
# R2 score on training data:  100.0
# Mean absolute error:  5.666666666666667
# Mean squared error:  41.0
# Root Mean squared error:  6.4031242374328485

# %% [markdown]
# #### 3. KNeighbors Regressor

# %%
KNR = KNeighborsRegressor()
KNR.fit(x_train,y_train)
predKNR=KNR.predict(x_test)
pred_train=KNR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predKNR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predKNR))
print('Mean squared error: ',mean_squared_error(y_test, predKNR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predKNR)))
# Out:
# R2 Score:  0.625005696923661
# R2 score on training data:  61.154076676655976
# Mean absolute error:  4.333333333333333
# Mean squared error:  27.426666666666677
# Root Mean squared error:  5.2370475142647575

# %% [markdown]
# #### 4. Support Vector Regressor

# %%
print('SVR for Poly kernel')
SVRR = SVR(kernel='poly')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
print('\n')

print('SVR for linear Kernel')
SVRR = SVR(kernel='linear')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
print('\n')

print('SVR for rbf Kernel')
SVRR = SVR(kernel='rbf')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
# Out:
# SVR for Poly kernel
# R2 Score:  0.03692156627900378
# R2 score on training data:  41.244925672631716
# Mean absolute error:  6.789406357366301
# Mean squared error:  70.43848655520507
# Root Mean squared error:  8.392763940157323
#
#
# SVR for linear Kernel
# R2 Score:  0.8290841457862541
# R2 score on training data:  90.05762358449788
# Mean absolute error:  2.6584971268308095
# Mean squared error:  12.500595670688691
# Root Mean squared error:  3.5356181454858344
#
#
# SVR for rbf Kernel
# R2 Score:  0.0473967332924321
# R2 score on training data:  21.83064905769696
# Mean absolute error:  6.570855095155902
# Mean squared error:  69.6723444789174
# Root Mean squared error:  8.346996135072628

# %% [markdown]
# The SVR for Linear Kernel is working well for the dataset.

# %%
SVRR = SVR(kernel='linear')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
# Out:
# R2 Score:  0.8290841457862541
# R2 score on training data:  90.05762358449788
# Mean absolute error:  2.6584971268308095
# Mean squared error:  12.500595670688691
# Root Mean squared error:  3.5356181454858344

# %% [markdown]
# #### 5. Lasso

# %%
LAR = Lasso()
LAR.fit(x_train,y_train)
predLAR=LAR.predict(x_test)
pred_train=LAR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predLAR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predLAR))
print('Mean squared error: ',mean_squared_error(y_test, predLAR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predLAR)))
# Out:
# R2 Score:  0.8887137678283791
# R2 score on training data:  89.54049670646694
# Mean absolute error:  2.5739342019416918
# Mean squared error:  8.139351369663276
# Root Mean squared error:  2.8529548488651684

# %% [markdown]
# #### 6. Ridge

# %%
RR = Ridge()
RR.fit(x_train,y_train)
predRR=RR.predict(x_test)
pred_train=RR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predRR))
print('Mean squared error: ',mean_squared_error(y_test, predRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predRR)))
# Out:
# R2 Score:  0.8604103293836012
# R2 score on training data:  93.80396264105661
# Mean absolute error:  2.632664281918615
# Mean squared error:  10.209433409249394
# Root Mean squared error:  3.195220400731285

# %% [markdown]
# #### 7. Elastic Net

# %%
ENR = ElasticNet()
ENR.fit(x_train,y_train)
predENR=ENR.predict(x_test)
pred_train=ENR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predENR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predENR))
print('Mean squared error: ',mean_squared_error(y_test, predENR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predENR)))
# Out:
# R2 Score:  0.8846469227223693
# R2 score on training data:  85.46081729735954
# Mean absolute error:  2.694164519342342
# Mean squared error:  8.436795902000043
# Root Mean squared error:  2.9046163089124253

# %% [markdown]
# #### 8. Random Forest Regressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predRFR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predRFR))
print('Mean squared error: ',mean_squared_error(y_test, predRFR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predRFR)))
# Out:
# R2 Score:  0.8291631598936573
# R2 score on training data:  93.52246684578553
# Mean absolute error:  3.198333333333333
# Mean squared error:  12.494816666666672
# Root Mean squared error:  3.534800795895954

# %% [markdown]
# #### 9. Gradient Boosting Regressor

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predGBR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predGBR))
print('Mean squared error: ',mean_squared_error(y_test, predGBR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predGBR)))
# Out:
# R2 Score:  0.5714630461607297
# R2 score on training data:  99.9999916906815
# Mean absolute error:  4.955497049520893
# Mean squared error:  31.342716651633296
# Root Mean squared error:  5.598456631218402

# %% [markdown]
# #### 10. Ada Boost Regressor

# %%
ABR = AdaBoostRegressor()
ABR.fit(x_train,y_train)
predABR=ABR.predict(x_test)
pred_train=ABR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predABR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predABR))
print('Mean squared error: ',mean_squared_error(y_test, predABR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predABR)))
# Out:
# R2 Score:  0.7497908773890197
# R2 score on training data:  99.14011099959141
# Mean absolute error:  3.7386363636363646
# Mean squared error:  18.300017217630863
# Root Mean squared error:  4.277851939657433

# %% [markdown]
# #### 11. Extra Trees Regressor

# %%
ETR = ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predETR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predETR))
print('Mean squared error: ',mean_squared_error(y_test, predETR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predETR)))
# Out:
# R2 Score:  0.9084363083934678
# R2 score on training data:  100.0
# Mean absolute error:  2.0433333333333317
# Mean squared error:  6.696866666666651
# Root Mean squared error:  2.587830494191351

# %% [markdown]
# ## Cross Validation to avoid overfitting and underfitting

# %%
from sklearn.model_selection import cross_val_score
print('Linear Regression Scores')
score1=cross_val_score(LRR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predLRR)-score1.mean())*100)
s1=(r2_score(y_test,predLRR)-score1.mean())*100
s11=(score1.mean())*100
# Out:
# Linear Regression Scores
# [ 0.62468093 -0.45907175  0.67840452  0.53537011  0.55292871]
# 0.3864625037511097
# Difference between R2 score and CV score is -  39.96996172421983

# %%
print('Decision Tree Scores')
score2=cross_val_score(DTR,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predDTR)-score2.mean())*100)
s2=(r2_score(y_test,predDTR)-score2.mean())*100
s22=(score2.mean())*100
# Out:
# Decision Tree Scores
# [-2.38181818 -9.81578947  0.03053116  0.33770492  0.57252358]
# -2.251369598810572
# Difference between R2 score and CV score is -  269.0792310546235

# %%
print('KNeighbors Regression Scores')
score3=cross_val_score(KNR,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predKNR)-score3.mean())*100)
s3=(r2_score(y_test,predKNR)-score3.mean())*100
s33=(score3.mean())*100
# Out:
# KNeighbors Regression Scores
# [ 0.29186364 -1.83789474  0.38081138  0.31134426  0.74021226]
# -0.022732639607827253
# Difference between R2 score and CV score is -  64.77383365314883

# %%
print('Support Vector Regression Scores')
score4=cross_val_score(SVRR,x,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predSVRR)-score4.mean())*100)
s4=(r2_score(y_test,predSVRR)-score4.mean())*100
s44=(score4.mean())*100
# Out:
# Support Vector Regression Scores
# [ 0.63484983 -1.19510769  0.82206571  0.89874701  0.73947901]
# 0.3800067742430892
# Difference between R2 score and CV score is -  44.90773715431649

# %%
print('Lasso Scores')
score5=cross_val_score(LAR,x,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predLAR)-score5.mean())*100)
s5=(r2_score(y_test,predLAR)-score5.mean())*100
s55=(score5.mean())*100
# Out:
# Lasso Scores
# [ 0.74994852 -0.62489687  0.75601352  0.78038971  0.88079185]
# 0.508449346525203
# Difference between R2 score and CV score is -  38.026442130317605

# %%
print('Ridge Scores')
score6=cross_val_score(RR,x,y)
print(score6)
print(score6.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predRR)-score6.mean())*100)
s6=(r2_score(y_test,predRR)-score6.mean())*100
s66=(score6.mean())*100
# Out:
# Ridge Scores
# [ 0.59172864 -0.85336258  0.68526166  0.91668429  0.82880545]
# 0.4338234925326452
# Difference between R2 score and CV score is -  42.658683685095596

# %%
print('Elastic Net Scores')
score7=cross_val_score(ENR,x,y)
print(score7)
print(score7.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predENR)-score7.mean())*100)
s7=(r2_score(y_test,predENR)-score7.mean())*100
s77=(score7.mean())*100
# Out:
# Elastic Net Scores
# [ 0.55690711 -0.76517785  0.65153782  0.63451254  0.90450902]
# 0.3964577268223163
# Difference between R2 score and CV score is -  48.81891959000531

# %%
print('Random Forest Scores')
score8=cross_val_score(RFR,x,y)
print(score8)
print(score8.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predRFR)-score8.mean())*100)
s8=(r2_score(y_test,predRFR)-score8.mean())*100
s88=(score8.mean())*100
# Out:
# Random Forest Scores
# [ 0.43196125 -5.18074474  0.48096947  0.42267869  0.85146079]
# -0.5987349078763378
# Difference between R2 score and CV score is -  142.7898067769995

# %%
print('Gradient Boosting Scores')
score9=cross_val_score(GBR,x,y)
print(score9)
print(score9.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predGBR)-score9.mean())*100)
s9=(r2_score(y_test,predGBR)-score9.mean())*100
s99=(score9.mean())*100
# Out:
# Gradient Boosting Scores
# [ 0.17705079 -8.87853156  0.49431388  0.56535761  0.7619482 ]
# -1.3759722163439605
# Difference between R2 score and CV score is -  194.74352625046902

# %%
print('Ada Boost Scores')
score10=cross_val_score(ABR,x,y)
print(score10)
print(score10.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predABR)-score10.mean())*100)
s10=(r2_score(y_test,predABR)-score10.mean())*100
s1010=(score10.mean())*100
# Out:
# Ada Boost Scores
# [ 0.29352652 -7.23504751  0.33409708  0.39175997  0.74185584]
# -1.0947616235169213
# Difference between R2 score and CV score is -  184.4552500905941

# %%
print('Extra Trees Scores')
score11=cross_val_score(ETR,x,y)
print(score11)
print(score11.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predETR)-score11.mean())*100)
s111=(r2_score(y_test,predETR)-score11.mean())*100
s1011=(score11.mean())*100
# Out:
# Extra Trees Scores
# [ 0.18664443 -3.99984605  0.60102903  0.28751623  0.82812028]
# -0.4193072165547983
# Difference between R2 score and CV score is -  132.77435249482662

# %%
diction={'Models':['LinearRegression','DecisionTreeRegressor','KNeighborsRegressor','SVR','Lasso','Ridge','ElasticNet','RandomForestRegressor','GradientBoostingRegressor','AdaBoostRegressor','Extra Trees Regressor'],'CV mean':[s11,s22,s33,s44,s55,s66,s77,s88,s99,s1010,s1011],'difference btw r2 and cv':[s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s111]}
dcvmrm=pd.DataFrame(diction)
dcvmrm
# Out:
#                        Models     CV mean  difference btw r2 and cv
# 0            LinearRegression   38.646250                 39.969962
# 1       DecisionTreeRegressor -225.136960                269.079231
# 2         KNeighborsRegressor   -2.273264                 64.773834
# 3                         SVR   38.000677                 44.907737
# 4                       Lasso   50.844935                 38.026442
# 5                       Ridge   43.382349                 42.658684
# 6                  ElasticNet   39.645773                 48.818920
# 7       RandomForestRegressor  -59.873491                142.789807
# 8   GradientBoostingRegressor -137.597222                194.743526
# 9           AdaBoostRegressor -109.476162                184.455250
# 10      Extra Trees Regressor  -41.930722                132.774352

# %%
plt.figure(figsize=(20,10))
sns.barplot(y=dcvmrm['CV mean'],x=dcvmrm.index,data=dcvmrm)
# Out:
# <AxesSubplot:ylabel='CV mean'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(y=dcvmrm['difference btw r2 and cv'],x=dcvmrm.index,data=dcvmrm)
# Out:
# <AxesSubplot:ylabel='difference btw r2 and cv'>

# %% [markdown]
# Compairing the Cross validation and difference between r2 and cv mean the best model is Ridge.

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'alpha':[.0001,.001,.01,.1,1,10,100,500,1000],'fit_intercept':['True','False'],'solver':['auto','svd','Isqr','sag','saga','cholesky','sparse_cg','lbfgs'],'max_iter':[5,10,15,30,50,100,200,500]}
GCV=GridSearchCV(RR,parameters)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 500,
#                                    1000],
#                          'fit_intercept': ['True', 'False'],
#                          'max_iter': [5, 10, 15, 30, 50, 100, 200, 500],
#                          'solver': ['auto', 'svd', 'Isqr', 'sag', 'saga',
#                                     'cholesky', 'sparse_cg', 'lbfgs']})

# %%
best_parameters = GCV.best_params_
print(best_parameters)
best_result=GCV.best_score_
print(best_result)
# Out:
# {'alpha': 0.1, 'fit_intercept': 'True', 'max_iter': 5, 'solver': 'saga'}
# 0.6977519014092376

# %%
Final_model=Ridge(alpha=0.1, fit_intercept=True, max_iter=5, solver='saga')
Final_model.fit(x_train,y_train)
pred = Final_model.predict(x_test)
print("R2 Score: ", r2_score(y_test,pred))
print('Mean absolute error: ',mean_absolute_error(y_test, pred))
print('Mean squared error: ',mean_squared_error(y_test, pred))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2 Score:  0.8688407062154961
# Mean absolute error:  2.6307226142253675
# Mean squared error:  9.592845014849962
# Root Mean squared error:  3.0972318309822984

# %% [markdown]
# # Saving the model

# %%
import pickle
filename='BaseballCase.pkl'
pickle.dump(Final_model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('BaseballCase.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 86.88407062154961

# %%
prediction=loaded_model.predict(x_test)
a=np.array(y_test)
df4=pd.DataFrame()
df4["Predicted"]=prediction
df4["Original"] = a
df4
# Out:
#    Predicted  Original
# 0  83.204198        79
# 1  70.945684        76
# 2  77.559357        76
# 3  92.401965        92
# 4  82.468254        81
# 5  59.903754        63
