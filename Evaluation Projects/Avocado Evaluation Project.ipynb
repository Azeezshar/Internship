# %% [markdown]
# Importing Important Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing the Dataset

# %%
df=pd.read_excel('avocadoo.xlsx')
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.shape
# Out:
# (18249, 14)

# %% [markdown]
# The dataset contains 18249 rows and 14 columns

# %%
df.columns
# Out:
# Index([  'Unnamed: 0',         'Date', 'AveragePrice', 'Total Volume',
#                  4046,           4225,           4770,   'Total Bags',
#          'Small Bags',   'Large Bags',  'XLarge Bags',         'type',
#                'year',       'region'],
#       dtype='object')

# %% [markdown]
# The column names are given above.

# %%
df.dtypes
# Out:
# Unnamed: 0               int64
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %% [markdown]
# We have two int64, 2 object, 1 datetime64 and 9 float64 data types present in the dataset.

# %%
#checking for null values through heatmap and info function
df.info()

sns.heatmap(df.isnull())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  datetime64[ns]
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: datetime64[ns](1), float64(9), int64(2), object(2)
# memory usage: 1.9+ MB
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# As we can see there are no null values present in our data.

# %%
#checking the nunique values in all columns
df.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %% [markdown]
# Here we can see the number of unique values present in each column.

# %%
for i in df.columns:
    x = df[i].value_counts()
    print("\nColumn name is:",i,"and it value is:\n",x)
# Out:
# Column name is: Unnamed: 0 and it value is:
#  0     432
# 7     432
# 1     432
# 11    432
# 9     432
# 8     432
# 10    432
# 6     432
# 5     432
# 4     432
# 3     432
# 2     432
# 41    324
# 34    324
# 35    324
# 36    324
# 37    324
# 38    324
# 39    324
# 40    324
# 47    324
# 42    324
# 43    324
# 44    324
# 45    324
# 46    324
# 32    324
# 48    324
# 49    324
# 50    324
# 33    324
# 26    324
# 31    324
# 30    324
# 12    324
# 13    324
# 14    324
# 15    324
# 16    324
# 17    324
# 18    324
# 19    324
# 20    324
# 21    324
# 22    324
# 23    324
# 24    324
# 25    324
# 27    324
# 28    324
# 29    324
# 51    322
# 52    107
# Name: Unnamed: 0, dtype: int64
#
# Column name is: Date and it value is:
#  2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64
#
# Column name is: AveragePrice and it value is:
#  1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64
#
# Column name is: Total Volume and it value is:
#  4103.97       2
# 3529.44       2
# 46602.16      2
# 13234.04      2
# 3713.49       2
#              ..
# 874349.55     1
# 1621253.97    1
# 830499.38     1
# 845065.66     1
# 17489.58      1
# Name: Total Volume, Length: 18237, dtype: int64
#
# Column name is: 4046 and it value is:
#  0.00       242
# 3.00        10
# 4.00         8
# 1.24         8
# 1.00         8
#           ...
# 1486.31      1
# 1761.80      1
# 1772.26      1
# 1803.39      1
# 2894.77      1
# Name: 4046, Length: 17702, dtype: int64
#
# Column name is: 4225 and it value is:
#  0.00         61
# 177.87        3
# 215.36        3
# 1.30          3
# 1.26          3
#              ..
# 417905.67     1
# 275986.91     1
# 277789.30     1
# 378155.00     1
# 2356.13       1
# Name: 4225, Length: 18103, dtype: int64
#
# Column name is: 4770 and it value is:
#  0.00      5497
# 2.66         7
# 3.32         7
# 10.97        6
# 1.59         6
#           ...
# 547.08       1
# 155.87       1
# 72.01        1
# 128.06       1
# 224.53       1
# Name: 4770, Length: 12071, dtype: int64
#
# Column name is: Total Bags and it value is:
#  0.00         15
# 990.00        5
# 300.00        5
# 550.00        4
# 266.67        4
#              ..
# 90196.05      1
# 130858.02     1
# 510679.10     1
# 84522.00      1
# 12014.15      1
# Name: Total Bags, Length: 18097, dtype: int64
#
# Column name is: Small Bags and it value is:
#  0.00        159
# 203.33       11
# 223.33       10
# 533.33       10
# 123.33        8
#            ...
# 14002.00      1
# 32441.00      1
# 29560.96      1
# 22077.20      1
# 11988.14      1
# Name: Small Bags, Length: 17321, dtype: int64
#
# Column name is: Large Bags and it value is:
#  0.00          2370
# 3.33           187
# 6.67            78
# 10.00           47
# 4.44            38
#               ...
# 2528089.14       1
# 2287449.76       1
# 731388.25        1
# 673464.14        1
# 26.01            1
# Name: Large Bags, Length: 15082, dtype: int64
#
# Column name is: XLarge Bags and it value is:
#  0.00       12048
# 3.33          29
# 6.67          16
# 1.11          15
# 5.00          12
#            ...
# 3018.05        1
# 2739.44        1
# 9301.67        1
# 8640.00        1
# 24.18          1
# Name: XLarge Bags, Length: 5588, dtype: int64
#
# Column name is: type and it value is:
#  conventional    9126
# organic         9123
# Name: type, dtype: int64
#
# Column name is: year and it value is:
#  2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64
#
# Column name is: region and it value is:
#  Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %% [markdown]
# Observations:
# 1. From the above we can see that the column "Unnamed: 0" does not play any significant role hence we can drop it.
# 2. For the Column "Type" we have 9126 conventional and 9123 organic.
# 3. There are 54 different Regions from which the data was observed.
# 4. There are zero values present in 4046, 4225, 4770, Total Bags, Small Bags, Large Bags XLarge Bags. They seem to be valid since there is a possibility of presence of a legitimate zero value.

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.shape
# Out:
# (18249, 13)

# %%
# converting the date column to integer columns
df['Day'] = df['Date'].dt.day
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Day  Month  Year
# 0  Albany   27     12  2015
# 1  Albany   20     12  2015
# 2  Albany   13     12  2015
# 3  Albany    6     12  2015
# 4  Albany   29     11  2015

# %%
df['Year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: Year, dtype: int64

# %%
df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# As we can see the "Year" and "year" columns are same. we can drop one of them. We can also drop the "Date" Column too as we have converted it to integers.

# %%
df.drop(['year'],axis=1, inplace=True)
df.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  region  Day  \
# 0     8696.87     8603.62       93.25          0.0  conventional  Albany   27
# 1     9505.56     9408.07       97.49          0.0  conventional  Albany   20
# 2     8145.35     8042.21      103.14          0.0  conventional  Albany   13
# 3     5811.16     5677.40      133.76          0.0  conventional  Albany    6
# 4     6183.95     5986.26      197.69          0.0  conventional  Albany   29
#
#    Month  Year
# 0     12  2015
# 1     12  2015
# 2     12  2015
# 3     12  2015
# 4     11  2015

# %%
df.shape
# Out:
# (18249, 15)

# %% [markdown]
# # Data Visualization

# %%
print(df['Year'].value_counts())
sns.set_style("whitegrid")
sns.countplot(x='Year',data=df)
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: Year, dtype: int64
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %% [markdown]
# 2017 was the best year for the sale count of Avocado as per the above analysis. 2015 and 2016 have the same number.

# %%
print(df['Month'].value_counts())
sns.countplot(x='Month',data=df)
# Out:
# 1     1944
# 3     1836
# 2     1728
# 10    1512
# 7     1512
# 5     1512
# 11    1404
# 8     1404
# 4     1404
# 12    1403
# 9     1296
# 6     1294
# Name: Month, dtype: int64
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %% [markdown]
# The first 3 months(Jan, Feb and March) seems to have the best sale count among all the other months.

# %%
print(df['type'].value_counts())
sns.countplot(x='type',data=df)
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64
# <AxesSubplot:xlabel='type', ylabel='count'>

# %% [markdown]
# The sale count of Organic and conventional avocados seems to be spread equally in the dataset.

# %%
print(df['Day'].value_counts())
plt.figure(figsize=(8,8))
sns.countplot(x='Day',data=df)
# Out:
# 4     756
# 11    756
# 18    755
# 25    755
# 1     648
# 26    648
# 5     648
# 12    648
# 3     648
# 8     648
# 15    648
# 22    648
# 24    648
# 17    648
# 10    648
# 19    648
# 7     540
# 14    540
# 21    540
# 28    540
# 27    540
# 20    540
# 29    540
# 13    540
# 6     539
# 2     432
# 9     432
# 23    432
# 30    432
# 31    432
# 16    432
# Name: Day, dtype: int64
# <AxesSubplot:xlabel='Day', ylabel='count'>

# %% [markdown]
# The sale count on 4,11,18,25 days are most as per the above analysis. The Least is on 2,9,16,23,30,31.

# %%
print(df['region'].value_counts())
plt.figure(figsize=(20,10))
sns.countplot(x='region',data=df)
plt.xticks(rotation=90)
plt.show()
# Out:
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Date',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %% [markdown]
# Above we can see how the Average price has varied along the date. The price was least on 2016-05 and 2017-01.

# %%
plt.figure(figsize=(15,10))
sns.lineplot(x='Month',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='AveragePrice'>

# %% [markdown]
# From the above we can see how the price is varied along the months. The lowest is in february and rises in the month of march and april. It again falls in May. After May it rises till the month of October and falls in november.

# %%
plt.figure(figsize=(10,8))
sns.lineplot(x='Day',y='AveragePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Day', ylabel='AveragePrice'>

# %% [markdown]
# The above graph shows how the average price varies by days.

# %%
plt.figure(figsize=(10,15))
sns.catplot(x="type", y="AveragePrice", hue="Year", kind="bar", data=df)
plt.show()

# %%
price_organic_conventional = df.groupby('type',as_index=False)
plt.figure(figsize=(15,10))
price_organic_conventional['AveragePrice'].plot()
plt.title('Average Price Per type')
# Out:
# Text(0.5, 1.0, 'Average Price Per type')

# %% [markdown]
# From the above 2 graphs we can see that the average price of Organic avocado is more when compared to the conventional avocado.

# %%
byRegion=df.groupby('region').mean()
byRegion.sort_values(by=['AveragePrice'], ascending=False, inplace=True)
plt.figure(figsize=(20,10))
sns.barplot(x = byRegion.index,y=byRegion["AveragePrice"],data = byRegion)
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price According to Region')
# Out:
# Text(0.5, 1.0, 'Average Price According to Region')

# %% [markdown]
# The above graph shows the mean average price of avocado at different regions.

# %%
plt.figure(figsize=(10,15))
sns.catplot(x="type", y="Total Volume", hue="Year", kind="bar", data=df)
plt.show()

# %% [markdown]
# The above graph shows the total volume of Avocados be it conventional and organic sold per year. It clearly shows the Conventional Avocados sold were more compared to organic.

# %%
plt.figure(figsize=(10,15))
sns.catplot(x="type", y="Total Bags", hue="Year", data=df, kind="bar")
plt.show()

# %% [markdown]
# from the above we can see that the conventional avocados bags were sold more compared to organic avocados bags.

# %%
# removing the Date column from the dataset
df.drop(['Date'],axis=1, inplace=True)
df.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  region  Day  Month  Year
# 0     8603.62       93.25          0.0  conventional  Albany   27     12  2015
# 1     9408.07       97.49          0.0  conventional  Albany   20     12  2015
# 2     8042.21      103.14          0.0  conventional  Albany   13     12  2015
# 3     5677.40      133.76          0.0  conventional  Albany    6     12  2015
# 4     5986.26      197.69          0.0  conventional  Albany   29     11  2015

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags           Day  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507     15.662612
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      8.776281
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000      1.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000      8.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000     16.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000     23.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000     31.000000
#
#               Month          Year
# count  18249.000000  18249.000000
# mean       6.177215   2016.147899
# std        3.534130      0.939938
# min        1.000000   2015.000000
# 25%        3.000000   2015.000000
# 50%        6.000000   2016.000000
# 75%        9.000000   2017.000000
# max       12.000000   2018.000000

# %% [markdown]
# Observations:
# 1. The STD is more for Total Volume, 4046, 4225, 4770, total Bags, small bags and Large bags. It means the spread of data is high.
# 2. The Mean and Median(50%) is differing for total volume, 4046, total bags and Large bags. Which means there is skewness in these columns.
# 3. The XLarge Bags column contains 0 which seems to be valid since there is a possibility of presence of a legitimate zero value.
# 4. The 75% and Max values have huge difference for columns Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags and XLarge Bags. There are outliers present in these columns.

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# region           object
# Day               int64
# Month             int64
# Year              int64
# dtype: object

# %% [markdown]
# ### Encoding the Categorical columns to Numerical columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Day  Month  Year
# 0         8603.62       93.25          0.0   0.0     0.0   27     12  2015
# 1         9408.07       97.49          0.0   0.0     0.0   20     12  2015
# 2         8042.21      103.14          0.0   0.0     0.0   13     12  2015
# 3         5677.40      133.76          0.0   0.0     0.0    6     12  2015
# 4         5986.26      197.69          0.0   0.0     0.0   29     11  2015
# ...           ...         ...          ...   ...     ...  ...    ...   ...
# 18244    13066.82      431.85          0.0   1.0    53.0    4      2  2018
# 18245     8940.04      324.80          0.0   1.0    53.0   28      1  2018
# 18246     9351.80       42.31          0.0   1.0    53.0   21      1  2018
# 18247    10919.54       50.00          0.0   1.0    53.0   14      1  2018
# 18248    11988.14       26.01          0.0   1.0    53.0    7      1  2018
#
# [18249 rows x 14 columns]

# %% [markdown]
# ### Checking for outliers

# %%
plt.figure(figsize=(20,15))
for i in enumerate(df.columns):
    plt.subplot(5,3,i[0]+1)
    sns.boxplot(df[i[1]])

# %% [markdown]
# The outliers is present in AveragePrice, Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags and XLarge Bags. We will not remove the outliers from Average price as it is our target variable.

# %% [markdown]
# ### Removing outliers

# %% [markdown]
# zscore Method

# %%
#Splitting the data to remove outliers
x= df.drop(['AveragePrice','type','region','Day','Month','Year'], axis=1)
print(x.shape)
# Out:
# (18249, 8)

# %%
x.head()
# Out:
#    Total Volume     4046       4225    4770  Total Bags  Small Bags  \
# 0      64236.62  1036.74   54454.85   48.16     8696.87     8603.62
# 1      54876.98   674.28   44638.81   58.33     9505.56     9408.07
# 2     118220.22   794.70  109149.67  130.50     8145.35     8042.21
# 3      78992.15  1132.00   71976.41   72.58     5811.16     5677.40
# 4      51039.60   941.48   43838.39   75.78     6183.95     5986.26
#
#    Large Bags  XLarge Bags
# 0       93.25          0.0
# 1       97.49          0.0
# 2      103.14          0.0
# 3      133.76          0.0
# 4      197.69          0.0

# %%
from scipy.stats import zscore
z=np.abs(zscore(x))
z
# Out:
#        Total Volume      4046      4225      4770  Total Bags  Small Bags  \
# 0          0.227716  0.230816  0.199902  0.212091    0.234170    0.232647
# 1          0.230427  0.231103  0.208054  0.211997    0.233350    0.231568
# 2          0.212085  0.231007  0.154478  0.211325    0.234730    0.233399
# 3          0.223444  0.230741  0.185350  0.211864    0.237096    0.236568
# 4          0.231538  0.230891  0.208719  0.211834    0.236718    0.236154
# ...             ...       ...       ...       ...         ...         ...
# 18244      0.241373  0.230017  0.243857  0.212540    0.229301    0.226665
# 18245      0.242296  0.230693  0.242277  0.212540    0.233594    0.232196
# 18246      0.242331  0.230693  0.243090  0.205766    0.233463    0.231644
# 18247      0.241625  0.230428  0.242651  0.205774    0.231866    0.229543
# 18248      0.241253  0.229347  0.243170  0.210450    0.230807    0.228111
#
#        Large Bags  XLarge Bags
# 0        0.222352      0.17558
# 1        0.222335      0.17558
# 2        0.222311      0.17558
# 3        0.222186      0.17558
# 4        0.221924      0.17558
# ...           ...          ...
# 18244    0.220964      0.17558
# 18245    0.221403      0.17558
# 18246    0.222561      0.17558
# 18247    0.222529      0.17558
# 18248    0.222628      0.17558
#
# [18249 rows x 8 columns]

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 346,  359,  780, ..., 9111, 9112, 9113], dtype=int64), array([1, 1, 7, ..., 6, 6, 6], dtype=int64))

# %%
z.iloc[346]
# Out:
# Total Volume    2.234545
# 4046            3.199411
# 4225            2.581200
# 4770            1.578563
# Total Bags      0.397641
# Small Bags      0.572525
# Large Bags      0.141836
# XLarge Bags     0.024443
# Name: 346, dtype: float64

# %%
df1=df[(z<3).all(axis=1)]
print(df.shape)
print(df1.shape)
# Out:
# (18249, 14)
# (17782, 14)

# %%
# Data loss percentage using zscore method
a=((18249-17782)/18249)*100
a
# Out:
# 2.55904433119623

# %% [markdown]
# IQR Method

# %%
Q1 = x.quantile(0.25)
Q3 = x.quantile(0.75)
IQR=Q3-Q1
df2=x[~((x < (Q1 - 1.5 * IQR)) | (x > (Q3 + 1.5 * IQR))).any(axis=1)]
df2.shape
# Out:
# (11747, 8)

# %%
# Data loss percentage using IQR method
b=((18249-11747)/18249)*100
b
# Out:
# 35.62934955340019

# %% [markdown]
# The Data loss percentage is 2.55% using zscore and 35.62% using IQR. Only 10% of data loss is acceptable. Hence i am selecting zscore method.

# %%
df=df1
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Day  Month  Year
# 0         8603.62       93.25          0.0   0.0     0.0   27     12  2015
# 1         9408.07       97.49          0.0   0.0     0.0   20     12  2015
# 2         8042.21      103.14          0.0   0.0     0.0   13     12  2015
# 3         5677.40      133.76          0.0   0.0     0.0    6     12  2015
# 4         5986.26      197.69          0.0   0.0     0.0   29     11  2015
# ...           ...         ...          ...   ...     ...  ...    ...   ...
# 18244    13066.82      431.85          0.0   1.0    53.0    4      2  2018
# 18245     8940.04      324.80          0.0   1.0    53.0   28      1  2018
# 18246     9351.80       42.31          0.0   1.0    53.0   21      1  2018
# 18247    10919.54       50.00          0.0   1.0    53.0   14      1  2018
# 18248    11988.14       26.01          0.0   1.0    53.0    7      1  2018
#
# [17782 rows x 14 columns]

# %% [markdown]
# ### Checking for skewness

# %%
df.skew()
# Out:
# AveragePrice    0.560969
# Total Volume    3.782060
# 4046            4.928850
# 4225            4.472729
# 4770            5.137120
# Total Bags      4.082103
# Small Bags      4.238647
# Large Bags      5.072468
# XLarge Bags     6.159391
# type           -0.052210
# region          0.005773
# Day             0.011251
# Month           0.098217
# Year            0.220792
# dtype: float64

# %%
plt.figure(figsize=(25,20))
for i in enumerate(df):
    plt.subplot(5,3,i[0]+1)
    sns.distplot(df[i[1]],color='g')

# %% [markdown]
# We can see there is skewness present in Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags and XLarge Bags.

# %%
print('Before removing skewness')
skewed=['Total Volume', 4046, 4225, 4770,'Total Bags','Small Bags','Large Bags','XLarge Bags']
plt.figure(figsize=(10,15))
for i in enumerate(skewed):
    plt.subplot(4,2,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# Before removing skewness

# %% [markdown]
# ### Removing skewness

# %%
# using power transform method
from sklearn.preprocessing import power_transform
df[['Total Volume', 4046, 4225, 4770, 'Total Bags', 'Small Bags','Large Bags','XLarge Bags']]=power_transform(df[['Total Volume', 4046, 4225, 4770, 'Total Bags', 'Small Bags','Large Bags','XLarge Bags']],method='yeo-johnson')

# %%
df.skew()
# Out:
# AveragePrice    0.560969
# Total Volume   -0.006809
# 4046           -0.038259
# 4225           -0.043246
# 4770            0.028015
# Total Bags     -0.021531
# Small Bags     -0.024657
# Large Bags     -0.110061
# XLarge Bags     0.860603
# type           -0.052210
# region          0.005773
# Day             0.011251
# Month           0.098217
# Year            0.220792
# dtype: float64

# %%
print('After removing skewness')
plt.figure(figsize=(10,10))
for i in enumerate(skewed):
    plt.subplot(4,2,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# After removing skewness

# %% [markdown]
# Here the skewness is removed from our numerical data

# %%
df
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0              1.33     -0.065094 -0.649918  0.358278 -0.212550   -0.527445
# 1              1.35     -0.137269 -0.770067  0.276355 -0.165117   -0.488205
# 2              0.93      0.215503 -0.724508  0.656010  0.034215   -0.556204
# 3              1.08      0.029840 -0.625017  0.475615 -0.110976   -0.702370
# 4              1.28     -0.170456 -0.677083  0.268966 -0.100289   -0.675712
# ...             ...           ...       ...       ...       ...         ...
# 18244          1.63     -0.668931 -0.454078 -0.922232 -1.224990   -0.331042
# 18245          1.71     -0.762380 -0.610403 -0.665649 -1.224990   -0.499550
# 18246          1.87     -0.766344 -0.610350 -0.774395  0.455355   -0.493424
# 18247          1.93     -0.692595 -0.539211 -0.711605  0.455045   -0.424475
# 18248          1.62     -0.658062 -0.351503 -0.787209  0.168008   -0.383676
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Day  Month  Year
# 0       -0.337064   -0.775214    -0.675702   0.0     0.0   27     12  2015
# 1       -0.301038   -0.765237    -0.675702   0.0     0.0   20     12  2015
# 2       -0.364044   -0.752534    -0.675702   0.0     0.0   13     12  2015
# 3       -0.500341   -0.693012    -0.675702   0.0     0.0    6     12  2015
# 4       -0.479918   -0.600755    -0.675702   0.0     0.0   29     11  2015
# ...           ...         ...          ...   ...     ...  ...    ...   ...
# 18244   -0.165765   -0.405895    -0.675702   1.0    53.0    4      2  2018
# 18245   -0.321645   -0.478556    -0.675702   1.0    53.0   28      1  2018
# 18246   -0.303466   -0.945246    -0.675702   1.0    53.0   21      1  2018
# 18247   -0.240252   -0.910471    -0.675702   1.0    53.0   14      1  2018
# 18248   -0.201685   -1.042930    -0.675702   1.0    53.0    7      1  2018
#
# [17782 rows x 14 columns]

# %% [markdown]
# # Correlation between variables

# %%
dfcor=df.corr()
dfcor
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.576829 -0.548618 -0.448579 -0.491320
# Total Volume     -0.576829      1.000000  0.889083  0.924160  0.818568
# 4046             -0.548618      0.889083  1.000000  0.764679  0.736523
# 4225             -0.448579      0.924160  0.764679  1.000000  0.796799
# 4770             -0.491320      0.818568  0.736523  0.796799  1.000000
# Total Bags       -0.564616      0.939776  0.799354  0.818511  0.761641
# Small Bags       -0.493621      0.905098  0.778765  0.784901  0.754305
# Large Bags       -0.477879      0.681427  0.601899  0.614878  0.548457
# XLarge Bags      -0.387285      0.629592  0.573880  0.584508  0.616413
# type              0.608447     -0.800828 -0.725826 -0.747722 -0.780988
# region            0.010428      0.065709  0.159390  0.032273  0.037805
# Day               0.024742     -0.006248 -0.004558 -0.005919  0.001383
# Month             0.157900     -0.026332 -0.025919 -0.024708 -0.017377
# Year              0.099910      0.076584 -0.002396 -0.004533 -0.051657
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      type  \
# AveragePrice   -0.564616   -0.493621   -0.477879    -0.387285  0.608447
# Total Volume    0.939776    0.905098    0.681427     0.629592 -0.800828
# 4046            0.799354    0.778765    0.601899     0.573880 -0.725826
# 4225            0.818511    0.784901    0.614878     0.584508 -0.747722
# 4770            0.761641    0.754305    0.548457     0.616413 -0.780988
# Total Bags      1.000000    0.949901    0.729652     0.613698 -0.725686
# Small Bags      0.949901    1.000000    0.566307     0.603334 -0.720466
# Large Bags      0.729652    0.566307    1.000000     0.452650 -0.500026
# XLarge Bags     0.613698    0.603334    0.452650     1.000000 -0.665587
# type           -0.725686   -0.720466   -0.500026    -0.665587  1.000000
# region          0.065996    0.051985    0.086573    -0.020865  0.021970
# Day            -0.003703   -0.000535   -0.000876     0.010241 -0.002469
# Month          -0.014571   -0.010260   -0.016942     0.018751 -0.005044
# Year            0.210924    0.185955    0.190295     0.159574  0.007399
#
#                 region       Day     Month      Year
# AveragePrice  0.010428  0.024742  0.157900  0.099910
# Total Volume  0.065709 -0.006248 -0.026332  0.076584
# 4046          0.159390 -0.004558 -0.025919 -0.002396
# 4225          0.032273 -0.005919 -0.024708 -0.004533
# 4770          0.037805  0.001383 -0.017377 -0.051657
# Total Bags    0.065996 -0.003703 -0.014571  0.210924
# Small Bags    0.051985 -0.000535 -0.010260  0.185955
# Large Bags    0.086573 -0.000876 -0.016942  0.190295
# XLarge Bags  -0.020865  0.010241  0.018751  0.159574
# type          0.021970 -0.002469 -0.005044  0.007399
# region        1.000000  0.000751  0.002175 -0.003610
# Day           0.000751  1.000000  0.010456  0.004044
# Month         0.002175  0.010456  1.000000 -0.173166
# Year         -0.003610  0.004044 -0.173166  1.000000

# %%
plt.figure(figsize=(14,14))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
# 1. The columns Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags and XLarge Bags have moderate negative correlation with the target variable Average price.
# 2. Type column is highly positive correlated to the target variable Average price.
# 3. The columns Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags and XLarge Bags have high positive correlation with each other.
# 4. The type is highly negative correlated to the columns Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags and XLarge Bags.
#
# 5. When the Target variable is changed to region, then it does not have much correlation with other variables except for 4046 column. Which is also very less correlated.
#
# For our ML model to work well lets check the Multicolinearity problem keeping the Target variable as Average Price

# %%
DF = df.copy() # Copying the df to use the data set for Target variable as region.

# %% [markdown]
# # Checking Multicolinearity

# %%
#Splitting the data
x= df.drop(['AveragePrice'], axis=1)
y= df['AveragePrice']

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif_calc():
    vif=pd.DataFrame()
    vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
    vif["faetures"]=x.columns
    print(vif)

# %%
vif_calc()
# Out:
#     VIF Factor      faetures
# 0    52.077134  Total Volume
# 1     7.072356          4046
# 2    11.127418          4225
# 3     3.788243          4770
# 4    33.881816    Total Bags
# 5    16.578585    Small Bags
# 6     3.438188    Large Bags
# 7     1.973905   XLarge Bags
# 8     7.618908          type
# 9     4.219758        region
# 10    4.195715           Day
# 11    4.087945         Month
# 12   13.780167          Year

# %% [markdown]
# We can see that the total volume has large VIF value. We can remove this from our data set.

# %%
df.drop('Total Volume', axis=1, inplace=True)
df.head()
# Out:
#    AveragePrice      4046      4225      4770  Total Bags  Small Bags  \
# 0          1.33 -0.649918  0.358278 -0.212550   -0.527445   -0.337064
# 1          1.35 -0.770067  0.276355 -0.165117   -0.488205   -0.301038
# 2          0.93 -0.724508  0.656010  0.034215   -0.556204   -0.364044
# 3          1.08 -0.625017  0.475615 -0.110976   -0.702370   -0.500341
# 4          1.28 -0.677083  0.268966 -0.100289   -0.675712   -0.479918
#
#    Large Bags  XLarge Bags  type  region  Day  Month  Year
# 0   -0.775214    -0.675702   0.0     0.0   27     12  2015
# 1   -0.765237    -0.675702   0.0     0.0   20     12  2015
# 2   -0.752534    -0.675702   0.0     0.0   13     12  2015
# 3   -0.693012    -0.675702   0.0     0.0    6     12  2015
# 4   -0.600755    -0.675702   0.0     0.0   29     11  2015

# %%
#Splitting the data
x= df.drop(['AveragePrice'], axis=1)
y= df['AveragePrice']

# %%
vif_calc()
# Out:
#     VIF Factor     faetures
# 0     3.607204         4046
# 1     4.169859         4225
# 2     3.777803         4770
# 3    24.049034   Total Bags
# 4    16.577902   Small Bags
# 5     3.393557   Large Bags
# 6     1.956988  XLarge Bags
# 7     7.166481         type
# 8     4.192754       region
# 9     4.195391          Day
# 10    4.082645        Month
# 11   13.286918         Year

# %% [markdown]
# We can see that the VIF value of Total bags is more. Hence we can remove this too from the dataset.

# %%
df.drop('Total Bags', axis=1, inplace=True)
df.head()
# Out:
#    AveragePrice      4046      4225      4770  Small Bags  Large Bags  \
# 0          1.33 -0.649918  0.358278 -0.212550   -0.337064   -0.775214
# 1          1.35 -0.770067  0.276355 -0.165117   -0.301038   -0.765237
# 2          0.93 -0.724508  0.656010  0.034215   -0.364044   -0.752534
# 3          1.08 -0.625017  0.475615 -0.110976   -0.500341   -0.693012
# 4          1.28 -0.677083  0.268966 -0.100289   -0.479918   -0.600755
#
#    XLarge Bags  type  region  Day  Month  Year
# 0    -0.675702   0.0     0.0   27     12  2015
# 1    -0.675702   0.0     0.0   20     12  2015
# 2    -0.675702   0.0     0.0   13     12  2015
# 3    -0.675702   0.0     0.0    6     12  2015
# 4    -0.675702   0.0     0.0   29     11  2015

# %%
#Splitting the data
x= df.drop(['AveragePrice'], axis=1)
y= df['AveragePrice']

# %%
vif_calc()
# Out:
#     VIF Factor     faetures
# 0     3.599333         4046
# 1     4.055478         4225
# 2     3.772970         4770
# 3     3.562661   Small Bags
# 4     1.751930   Large Bags
# 5     1.956654  XLarge Bags
# 6     7.162515         type
# 7     4.192691       region
# 8     4.194687          Day
# 9     4.082585        Month
# 10   13.282272         Year

# %% [markdown]
# As we can see the VIF values for other columns is also reduced. We will not be removing any further data from the dataset.

# %% [markdown]
# # Feature Scaling using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x
# Out:
#            4046      4225      4770  Small Bags  Large Bags  XLarge Bags  \
# 0     -0.649918  0.358278 -0.212550   -0.337064   -0.775214    -0.675702
# 1     -0.770067  0.276355 -0.165117   -0.301038   -0.765237    -0.675702
# 2     -0.724508  0.656010  0.034215   -0.364044   -0.752534    -0.675702
# 3     -0.625017  0.475615 -0.110976   -0.500341   -0.693012    -0.675702
# 4     -0.677083  0.268966 -0.100289   -0.479918   -0.600755    -0.675702
# ...         ...       ...       ...         ...         ...          ...
# 17777 -0.454078 -0.922232 -1.224990   -0.165765   -0.405895    -0.675702
# 17778 -0.610403 -0.665649 -1.224990   -0.321645   -0.478556    -0.675702
# 17779 -0.610350 -0.774395  0.455355   -0.303466   -0.945246    -0.675702
# 17780 -0.539211 -0.711605  0.455045   -0.240252   -0.910471    -0.675702
# 17781 -0.351503 -0.787209  0.168008   -0.201685   -1.042930    -0.675702
#
#            type    region       Day     Month      Year
# 0     -1.026443 -1.698613  1.289235  1.641434 -1.214908
# 1     -1.026443 -1.698613  0.491750  1.641434 -1.214908
# 2     -1.026443 -1.698613 -0.305734  1.641434 -1.214908
# 3     -1.026443 -1.698613 -1.103219  1.641434 -1.214908
# 4     -1.026443 -1.698613  1.517088  1.358706 -1.214908
# ...         ...       ...       ...       ...       ...
# 17777  0.974238  1.742552 -1.331072 -1.185845  1.979143
# 17778  0.974238  1.742552  1.403161 -1.468572  1.979143
# 17779  0.974238  1.742552  0.605677 -1.468572  1.979143
# 17780  0.974238  1.742552 -0.191808 -1.468572  1.979143
# 17781  0.974238  1.742552 -0.989293 -1.468572  1.979143
#
# [17782 rows x 11 columns]

# %% [markdown]
# # Modelling

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score

# %% [markdown]
# Creating train test split and finding the best random_state

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
    RF = RandomForestRegressor()
    RF.fit(x_train,y_train)
    pred=RF.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Maximum r2 score is  ",maxAccu," At random state ",maxRS)
# Out:
# Maximum r2 score is   0.9013426799665508  At random state  66

# %% [markdown]
# random state 66

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=maxRS)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import Lasso,Ridge
from sklearn.linear_model import ElasticNet
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import ExtraTreesRegressor

# %% [markdown]
# #### 1. Linear Regression

# %%
LRR = LinearRegression()
LRR.fit(x_train,y_train)
predLRR=LRR.predict(x_test)
pred_train=LRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predLRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predLRR))
print('Mean squared error: ',mean_squared_error(y_test, predLRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predLRR)))
# Out:
# R2 Score:  0.5175484249937246
# R2 score on training data:  50.73268345738104
# Mean absolute error:  0.22071635714190482
# Mean squared error:  0.08063020213902765
# Root Mean squared error:  0.2839545775982977

# %% [markdown]
# #### 2. Decision Tree Regressor

# %%
print('DTR for squared_error')
DTR1 = DecisionTreeRegressor(criterion='squared_error')
DTR1.fit(x_train,y_train)
predDTR1=DTR1.predict(x_test)
pred_train=DTR1.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR1))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR1))
print('Mean squared error: ',mean_squared_error(y_test, predDTR1))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR1)))
print('\n')

print('DTR for friedman_mse')
DTR2 = DecisionTreeRegressor(criterion='friedman_mse')
DTR2.fit(x_train,y_train)
predDTR2=DTR2.predict(x_test)
pred_train=DTR2.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR2))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR2))
print('Mean squared error: ',mean_squared_error(y_test, predDTR2))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR2)))
print('\n')

print('DTR for absolute_error')
DTR3 = DecisionTreeRegressor(criterion='absolute_error')
DTR3.fit(x_train,y_train)
predDTR3=DTR3.predict(x_test)
pred_train=DTR3.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR3))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR3))
print('Mean squared error: ',mean_squared_error(y_test, predDTR3))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR3)))
print('\n')

print('DTR for poisson')
DTR4 = DecisionTreeRegressor(criterion='poisson')
DTR4.fit(x_train,y_train)
predDTR4=DTR4.predict(x_test)
pred_train=DTR4.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR4))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR4))
print('Mean squared error: ',mean_squared_error(y_test, predDTR4))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR4)))
# Out:
# DTR for squared_error
# R2 Score:  0.7754409264516444
# R2 score on training data:  100.0
# Mean absolute error:  0.12739387123980883
# Mean squared error:  0.03752965982569581
# Root Mean squared error:  0.193725733514409
#
#
# DTR for friedman_mse
# R2 Score:  0.7675219022733262
# R2 score on training data:  100.0
# Mean absolute error:  0.12921563114984538
# Mean squared error:  0.038853134664042735
# Root Mean squared error:  0.19711198508472977
#
#
# DTR for absolute_error
# R2 Score:  0.7404105655248514
# R2 score on training data:  100.0
# Mean absolute error:  0.1355018273826258
# Mean squared error:  0.043384143941523755
# Root Mean squared error:  0.20828860732532578
#
#
# DTR for poisson
# R2 Score:  0.3599190829888348
# R2 score on training data:  100.0
# Mean absolute error:  0.22522631430981163
# Mean squared error:  0.10697416362102895
# Root Mean squared error:  0.3270690502340889

# %% [markdown]
# We can see that Decision Tree Regressor is working well for squared_error criterion

# %%
DTR = DecisionTreeRegressor(criterion='squared_error')
DTR.fit(x_train,y_train)
predDTR=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predDTR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predDTR))
print('Mean squared error: ',mean_squared_error(y_test, predDTR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predDTR)))
# Out:
# R2 Score:  0.7768371347250755
# R2 score on training data:  100.0
# Mean absolute error:  0.12792240652235032
# Mean squared error:  0.03729631712116952
# Root Mean squared error:  0.19312254431103978

# %% [markdown]
# #### 3. KNeighbors Regressor

# %%
KNR = KNeighborsRegressor()
KNR.fit(x_train,y_train)
predKNR=KNR.predict(x_test)
pred_train=KNR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predKNR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predKNR))
print('Mean squared error: ',mean_squared_error(y_test, predKNR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predKNR)))
# Out:
# R2 Score:  0.8032129153115339
# R2 score on training data:  86.59202818667124
# Mean absolute error:  0.130716896260894
# Mean squared error:  0.03288823840314872
# Root Mean squared error:  0.18135114668275115

# %% [markdown]
# #### 4. Support Vector Regressor

# %%
print('SVR for Poly kernel')
SVRR = SVR(kernel='poly')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
print('\n')

print('SVR for linear Kernel')
SVRR = SVR(kernel='linear')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
print('\n')

print('SVR for rbf Kernel')
SVRR = SVR(kernel='rbf')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
# Out:
# SVR for Poly kernel
# R2 Score:  0.6590277710620811
# R2 score on training data:  66.41897065613274
# Mean absolute error:  0.1792462286324132
# Mean squared error:  0.056985324885096715
# Root Mean squared error:  0.23871599210169542
#
#
# SVR for linear Kernel
# R2 Score:  0.5125312091704488
# R2 score on training data:  50.449677882791164
# Mean absolute error:  0.2203810601723911
# Mean squared error:  0.0814687093529394
# Root Mean squared error:  0.28542724003314646
#
#
# SVR for rbf Kernel
# R2 Score:  0.7901163381955054
# R2 score on training data:  80.2791144004191
# Mean absolute error:  0.1373737599557944
# Mean squared error:  0.03507701695606567
# Root Mean squared error:  0.18728859270138604

# %% [markdown]
# The SVR for rbf Kernel is working well for the dataset.

# %%
SVRR = SVR(kernel='rbf')
SVRR.fit(x_train,y_train)
predSVRR=SVRR.predict(x_test)
pred_train=SVRR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predSVRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predSVRR))
print('Mean squared error: ',mean_squared_error(y_test, predSVRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predSVRR)))
# Out:
# R2 Score:  0.7901163381955054
# R2 score on training data:  80.2791144004191
# Mean absolute error:  0.1373737599557944
# Mean squared error:  0.03507701695606567
# Root Mean squared error:  0.18728859270138604

# %% [markdown]
# #### 5. Lasso

# %%
LAR = Lasso()
LAR.fit(x_train,y_train)
predLAR=LAR.predict(x_test)
pred_train=LAR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predLAR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predLAR))
print('Mean squared error: ',mean_squared_error(y_test, predLAR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predLAR)))
# Out:
# R2 Score:  -0.00033978384841715226
# R2 score on training data:  0.0
# Mean absolute error:  0.33099744902622763
# Mean squared error:  0.16718278716026566
# Root Mean squared error:  0.40887991777570304

# %% [markdown]
# Lasso is working badly on our dataset.

# %% [markdown]
# #### 6. Ridge

# %%
RR = Ridge()
RR.fit(x_train,y_train)
predRR=RR.predict(x_test)
pred_train=RR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predRR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predRR))
print('Mean squared error: ',mean_squared_error(y_test, predRR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predRR)))
# Out:
# R2 Score:  0.5175466239087254
# R2 score on training data:  50.73268211496732
# Mean absolute error:  0.22071520746770745
# Mean squared error:  0.08063050314716003
# Root Mean squared error:  0.28395510762646975

# %% [markdown]
# #### 7. Elastic Net

# %%
ENR = ElasticNet()
ENR.fit(x_train,y_train)
predENR=ENR.predict(x_test)
pred_train=ENR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predENR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predENR))
print('Mean squared error: ',mean_squared_error(y_test, predENR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predENR)))
# Out:
# R2 Score:  -0.00033978384841715226
# R2 score on training data:  0.0
# Mean absolute error:  0.33099744902622763
# Mean squared error:  0.16718278716026566
# Root Mean squared error:  0.40887991777570304

# %% [markdown]
#  Elastic Net is working badly on our dataset.

# %% [markdown]
# #### 8. Random Forest Regressor

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
predRFR=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predRFR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predRFR))
print('Mean squared error: ',mean_squared_error(y_test, predRFR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predRFR)))
# Out:
# R2 Score:  0.9004984001747277
# R2 score on training data:  98.36841499254837
# Mean absolute error:  0.09086407084621871
# Mean squared error:  0.016629304416643235
# Root Mean squared error:  0.12895466031378328

# %% [markdown]
# #### 9. Gradient Boosting Regressor

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
predGBR=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predGBR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predGBR))
print('Mean squared error: ',mean_squared_error(y_test, predGBR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predGBR)))
# Out:
# R2 Score:  0.7489403207759046
# R2 score on training data:  74.96427730360833
# Mean absolute error:  0.1543202605664818
# Mean squared error:  0.041958600061643384
# Root Mean squared error:  0.20483798490915542

# %% [markdown]
# #### 10. Ada Boost Regressor

# %%
ABR = AdaBoostRegressor()
ABR.fit(x_train,y_train)
predABR=ABR.predict(x_test)
pred_train=ABR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predABR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predABR))
print('Mean squared error: ',mean_squared_error(y_test, predABR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predABR)))
# Out:
# R2 Score:  0.5552600414159342
# R2 score on training data:  54.15680599829527
# Mean absolute error:  0.22053277753136638
# Mean squared error:  0.07432761051608043
# Root Mean squared error:  0.2726309052841963

# %% [markdown]
# #### 11. Extra Trees Regressor

# %%
ETR = ExtraTreesRegressor()
ETR.fit(x_train,y_train)
predETR=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print("R2 Score: ", r2_score(y_test,predETR))
print("R2 score on training data: ", r2_score(y_train,pred_train)*100)
print('Mean absolute error: ',mean_absolute_error(y_test, predETR))
print('Mean squared error: ',mean_squared_error(y_test, predETR))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, predETR)))
# Out:
# R2 Score:  0.9231867866029535
# R2 score on training data:  100.0
# Mean absolute error:  0.07870674725892604
# Mean squared error:  0.012837485136350857
# Root Mean squared error:  0.11330262634357094

# %% [markdown]
# # Cross Validation to avoid overfitting and underfitting

# %%
from sklearn.model_selection import cross_val_score
print('Linear Regression Scores')
score1=cross_val_score(LRR,x,y)
print(score1)
print(score1.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predLRR)-score1.mean())*100)
s1=(r2_score(y_test,predLRR)-score1.mean())*100
s11=(score1.mean())*100
# Out:
# Linear Regression Scores
# [-0.46696559  0.15859079  0.40817746  0.18035893  0.17373227]
# 0.0907787741268565
# Difference between R2 score and CV score is -  42.6769650866868

# %%
print('Decision Tree Scores')
score2=cross_val_score(DTR,x,y)
print(score2)
print(score2.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predDTR)-score2.mean())*100)
s2=(r2_score(y_test,predDTR)-score2.mean())*100
s22=(score2.mean())*100
# Out:
# Decision Tree Scores
# [-1.31539495 -0.06231784  0.18454224 -0.17287506 -0.33484862]
# -0.3401788474080011
# Difference between R2 score and CV score is -  111.70159821330765

# %%
print('KNeighbors Regression Scores')
score3=cross_val_score(KNR,x,y)
print(score3)
print(score3.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predKNR)-score3.mean())*100)
s3=(r2_score(y_test,predKNR)-score3.mean())*100
s33=(score3.mean())*100
# Out:
# KNeighbors Regression Scores
# [-0.40668118  0.23917489  0.42545235  0.01042207 -0.02682781]
# 0.04830806378749501
# Difference between R2 score and CV score is -  75.49048515240389

# %%
print('Support Vector Regression Scores')
score4=cross_val_score(SVRR,x,y)
print(score4)
print(score4.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predSVRR)-score4.mean())*100)
s4=(r2_score(y_test,predSVRR)-score4.mean())*100
s44=(score4.mean())*100
# Out:
# Support Vector Regression Scores
# [-0.47100376  0.45577919 -0.01221136  0.28908097 -0.02641167]
# 0.04704667288979445
# Difference between R2 score and CV score is -  74.30696653057109

# %%
print('Lasso Scores')
score5=cross_val_score(LAR,x,y)
print(score5)
print(score5.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predLAR)-score5.mean())*100)
s5=(r2_score(y_test,predLAR)-score5.mean())*100
s55=(score5.mean())*100
# Out:
# Lasso Scores
# [-4.0523001  -0.7293968  -0.05123348 -0.3845869  -0.78463738]
# -1.2004309324076277
# Difference between R2 score and CV score is -  120.00911485592106

# %%
print('Ridge Scores')
score6=cross_val_score(RR,x,y)
print(score6)
print(score6.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predRR)-score6.mean())*100)
s6=(r2_score(y_test,predRR)-score6.mean())*100
s66=(score6.mean())*100
# Out:
# Ridge Scores
# [-0.46684832  0.158656    0.40820593  0.18034104  0.17371687]
# 0.09081430232840319
# Difference between R2 score and CV score is -  42.67323215803222

# %%
print('Elastic Net Scores')
score7=cross_val_score(ENR,x,y)
print(score7)
print(score7.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predENR)-score7.mean())*100)
s7=(r2_score(y_test,predENR)-score7.mean())*100
s77=(score7.mean())*100
# Out:
# Elastic Net Scores
# [-4.0523001  -0.7293968  -0.05123348 -0.3845869  -0.78463738]
# -1.2004309324076277
# Difference between R2 score and CV score is -  120.00911485592106

# %%
print('Random Forest Scores')
score8=cross_val_score(RFR,x,y)
print(score8)
print(score8.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predRFR)-score8.mean())*100)
s8=(r2_score(y_test,predRFR)-score8.mean())*100
s88=(score8.mean())*100
# Out:
# Random Forest Scores
# [-0.20238664  0.48754323  0.56980252  0.30140706  0.00721967]
# 0.2327171665275177
# Difference between R2 score and CV score is -  66.778123364721

# %%
print('Gradient Boosting Scores')
score9=cross_val_score(GBR,x,y)
print(score9)
print(score9.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predGBR)-score9.mean())*100)
s9=(r2_score(y_test,predGBR)-score9.mean())*100
s99=(score9.mean())*100
# Out:
# Gradient Boosting Scores
# [0.12490496 0.5927507  0.65073892 0.35717342 0.20644016]
# 0.3864016303897468
# Difference between R2 score and CV score is -  36.253869038615775

# %%
print('Ada Boost Scores')
score10=cross_val_score(ABR,x,y)
print(score10)
print(score10.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predABR)-score10.mean())*100)
s10=(r2_score(y_test,predABR)-score10.mean())*100
s1010=(score10.mean())*100
# Out:
# Ada Boost Scores
# [-0.81815159  0.28612643  0.50607479  0.05033433  0.11435372]
# 0.027747536919613604
# Difference between R2 score and CV score is -  52.75125044963206

# %%
print('Extra Trees Scores')
score11=cross_val_score(ETR,x,y)
print(score11)
print(score11.mean())
print("Difference between R2 score and CV score is - ", (r2_score(y_test,predETR)-score11.mean())*100)
s111=(r2_score(y_test,predETR)-score11.mean())*100
s1011=(score11.mean())*100
# Out:
# Extra Trees Scores
# [-0.07068586  0.5013701   0.64424647  0.2890973   0.09753052]
# 0.2923117066642324
# Difference between R2 score and CV score is -  63.08750799387211

# %%
diction={'Models':['LinearRegression','DecisionTreeRegressor','KNeighborsRegressor','SVR','Lasso','Ridge','ElasticNet','RandomForestRegressor','GradientBoostingRegressor','AdaBoostRegressor','Extra Trees Regressor'],'CV mean':[s11,s22,s33,s44,s55,s66,s77,s88,s99,s1010,s1011],'difference btw r2 and cv':[s1,s2,s3,s4,s5,s6,s7,s8,s9,s10,s111]}
dcvmrm=pd.DataFrame(diction)
dcvmrm
# Out:
#                        Models     CV mean  difference btw r2 and cv
# 0            LinearRegression    9.077877                 42.676965
# 1       DecisionTreeRegressor  -34.017885                111.701598
# 2         KNeighborsRegressor    4.830806                 75.490485
# 3                         SVR    4.704667                 74.306967
# 4                       Lasso -120.043093                120.009115
# 5                       Ridge    9.081430                 42.673232
# 6                  ElasticNet -120.043093                120.009115
# 7       RandomForestRegressor   23.271717                 66.778123
# 8   GradientBoostingRegressor   38.640163                 36.253869
# 9           AdaBoostRegressor    2.774754                 52.751250
# 10      Extra Trees Regressor   29.231171                 63.087508

# %%
plt.figure(figsize=(20,10))
sns.barplot(y=dcvmrm['CV mean'],x=dcvmrm.index,data=dcvmrm)
# Out:
# <AxesSubplot:ylabel='CV mean'>

# %%
plt.figure(figsize=(20,10))
sns.barplot(y=dcvmrm['difference btw r2 and cv'],x=dcvmrm.index,data=dcvmrm)
# Out:
# <AxesSubplot:ylabel='difference btw r2 and cv'>

# %% [markdown]
# Compairing the Cross validation and difference between r2 and cv mean the best model is Gradient Boosting Regressor.

# %% [markdown]
# # Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
parameters={'n_estimators':[100,500,1000],
            'learning_rate':[.001,0.01,.1],
            'max_depth':[1,2,3,4],
            'subsample':[.5,.75,1],
            'random_state':[1,2,None]}
GCV=GridSearchCV(GBR,parameters)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(estimator=GradientBoostingRegressor(),
#              param_grid={'learning_rate': [0.001, 0.01, 0.1],
#                          'max_depth': [1, 2, 3, 4],
#                          'n_estimators': [100, 500, 1000],
#                          'random_state': [1, 2, None],
#                          'subsample': [0.5, 0.75, 1]})

# %%
best_parameters = GCV.best_params_
print(best_parameters)
best_result=GCV.best_score_
print(best_result)
# Out:
# {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 1000, 'random_state': 2, 'subsample': 0.75}
# 0.889170712782979

# %%
Final_model1=GradientBoostingRegressor(n_estimators=1000, learning_rate=0.1, max_depth=4, subsample=0.75, random_state = 2)
Final_model1.fit(x_train,y_train)
pred1 = Final_model1.predict(x_test)
print("R2 Score: ", r2_score(y_test,pred1))
print('Mean absolute error: ',mean_absolute_error(y_test, pred1))
print('Mean squared error: ',mean_squared_error(y_test, pred1))
print('Root Mean squared error: ',np.sqrt(mean_squared_error(y_test, pred1)))
# Out:
# R2 Score:  0.9040579259548396
# Mean absolute error:  0.092303858801619
# Mean squared error:  0.016034415109533472
# Root Mean squared error:  0.12662707099800372

# %% [markdown]
# # Saving the model1

# %%
import pickle
filename='Avocado1.pkl'
pickle.dump(Final_model1,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Avocado1.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 90.40579259548396

# %%
prediction=loaded_model.predict(x_test)
a=np.array(y_test)
df4=pd.DataFrame()
df4["Predicted"]=prediction
df4["Original"] = a
df4
# Out:
#       Predicted  Original
# 0      1.469971      1.47
# 1      1.580163      1.33
# 2      1.006453      1.15
# 3      1.363394      1.43
# 4      1.160444      1.09
# ...         ...       ...
# 3552   1.034980      0.99
# 3553   2.017444      1.76
# 3554   1.445816      1.54
# 3555   0.987627      0.98
# 3556   1.639637      1.53
#
# [3557 rows x 2 columns]

# %% [markdown]
# # Modelling for Target Variable as Region

# %%
DF
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0              1.33     -0.065094 -0.649918  0.358278 -0.212550   -0.527445
# 1              1.35     -0.137269 -0.770067  0.276355 -0.165117   -0.488205
# 2              0.93      0.215503 -0.724508  0.656010  0.034215   -0.556204
# 3              1.08      0.029840 -0.625017  0.475615 -0.110976   -0.702370
# 4              1.28     -0.170456 -0.677083  0.268966 -0.100289   -0.675712
# ...             ...           ...       ...       ...       ...         ...
# 18244          1.63     -0.668931 -0.454078 -0.922232 -1.224990   -0.331042
# 18245          1.71     -0.762380 -0.610403 -0.665649 -1.224990   -0.499550
# 18246          1.87     -0.766344 -0.610350 -0.774395  0.455355   -0.493424
# 18247          1.93     -0.692595 -0.539211 -0.711605  0.455045   -0.424475
# 18248          1.62     -0.658062 -0.351503 -0.787209  0.168008   -0.383676
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Day  Month  Year
# 0       -0.337064   -0.775214    -0.675702   0.0     0.0   27     12  2015
# 1       -0.301038   -0.765237    -0.675702   0.0     0.0   20     12  2015
# 2       -0.364044   -0.752534    -0.675702   0.0     0.0   13     12  2015
# 3       -0.500341   -0.693012    -0.675702   0.0     0.0    6     12  2015
# 4       -0.479918   -0.600755    -0.675702   0.0     0.0   29     11  2015
# ...           ...         ...          ...   ...     ...  ...    ...   ...
# 18244   -0.165765   -0.405895    -0.675702   1.0    53.0    4      2  2018
# 18245   -0.321645   -0.478556    -0.675702   1.0    53.0   28      1  2018
# 18246   -0.303466   -0.945246    -0.675702   1.0    53.0   21      1  2018
# 18247   -0.240252   -0.910471    -0.675702   1.0    53.0   14      1  2018
# 18248   -0.201685   -1.042930    -0.675702   1.0    53.0    7      1  2018
#
# [17782 rows x 14 columns]

# %%
# changing the region that has 54 value counts to 5 value counts
ranges = [(0, 11), (12, 22), (23, 33), (34, 44), (45, 54)]
class_values = [1, 2, 3, 4, 5]

DF['region'] = DF['region'].apply(lambda x: next((c for (r, c) in zip(ranges, class_values) if r[0] <= x <= r[1]), None))

# %%
DF
# Out:
#        AveragePrice  Total Volume      4046      4225      4770  Total Bags  \
# 0              1.33     -0.065094 -0.649918  0.358278 -0.212550   -0.527445
# 1              1.35     -0.137269 -0.770067  0.276355 -0.165117   -0.488205
# 2              0.93      0.215503 -0.724508  0.656010  0.034215   -0.556204
# 3              1.08      0.029840 -0.625017  0.475615 -0.110976   -0.702370
# 4              1.28     -0.170456 -0.677083  0.268966 -0.100289   -0.675712
# ...             ...           ...       ...       ...       ...         ...
# 18244          1.63     -0.668931 -0.454078 -0.922232 -1.224990   -0.331042
# 18245          1.71     -0.762380 -0.610403 -0.665649 -1.224990   -0.499550
# 18246          1.87     -0.766344 -0.610350 -0.774395  0.455355   -0.493424
# 18247          1.93     -0.692595 -0.539211 -0.711605  0.455045   -0.424475
# 18248          1.62     -0.658062 -0.351503 -0.787209  0.168008   -0.383676
#
#        Small Bags  Large Bags  XLarge Bags  type  region  Day  Month  Year
# 0       -0.337064   -0.775214    -0.675702   0.0       1   27     12  2015
# 1       -0.301038   -0.765237    -0.675702   0.0       1   20     12  2015
# 2       -0.364044   -0.752534    -0.675702   0.0       1   13     12  2015
# 3       -0.500341   -0.693012    -0.675702   0.0       1    6     12  2015
# 4       -0.479918   -0.600755    -0.675702   0.0       1   29     11  2015
# ...           ...         ...          ...   ...     ...  ...    ...   ...
# 18244   -0.165765   -0.405895    -0.675702   1.0       5    4      2  2018
# 18245   -0.321645   -0.478556    -0.675702   1.0       5   28      1  2018
# 18246   -0.303466   -0.945246    -0.675702   1.0       5   21      1  2018
# 18247   -0.240252   -0.910471    -0.675702   1.0       5   14      1  2018
# 18248   -0.201685   -1.042930    -0.675702   1.0       5    7      1  2018
#
# [17782 rows x 14 columns]

# %%
print(DF['region'].value_counts())
# Out:
# 1    4008
# 4    3718
# 3    3700
# 2    3645
# 5    2711
# Name: region, dtype: int64

# %%
#Dropping the columns with high VIF values
DF.drop('Total Volume', axis=1, inplace=True)
DF.drop('Total Bags', axis=1, inplace=True)
DF.head()
# Out:
#    AveragePrice      4046      4225      4770  Small Bags  Large Bags  \
# 0          1.33 -0.649918  0.358278 -0.212550   -0.337064   -0.775214
# 1          1.35 -0.770067  0.276355 -0.165117   -0.301038   -0.765237
# 2          0.93 -0.724508  0.656010  0.034215   -0.364044   -0.752534
# 3          1.08 -0.625017  0.475615 -0.110976   -0.500341   -0.693012
# 4          1.28 -0.677083  0.268966 -0.100289   -0.479918   -0.600755
#
#    XLarge Bags  type  region  Day  Month  Year
# 0    -0.675702   0.0       1   27     12  2015
# 1    -0.675702   0.0       1   20     12  2015
# 2    -0.675702   0.0       1   13     12  2015
# 3    -0.675702   0.0       1    6     12  2015
# 4    -0.675702   0.0       1   29     11  2015

# %%
#Splitting the data
x= DF.drop(['region'], axis=1)
y= DF['region']

# %% [markdown]
# ### Feature Scaling using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x=pd.DataFrame(st.fit_transform(x),columns=x.columns)
x
# Out:
#        AveragePrice      4046      4225      4770  Small Bags  Large Bags  \
# 0         -0.212660 -0.649918  0.358278 -0.212550   -0.337064   -0.775214
# 1         -0.162942 -0.770067  0.276355 -0.165117   -0.301038   -0.765237
# 2         -1.207026 -0.724508  0.656010  0.034215   -0.364044   -0.752534
# 3         -0.834139 -0.625017  0.475615 -0.110976   -0.500341   -0.693012
# 4         -0.336956 -0.677083  0.268966 -0.100289   -0.479918   -0.600755
# ...             ...       ...       ...       ...         ...         ...
# 17777      0.533114 -0.454078 -0.922232 -1.224990   -0.165765   -0.405895
# 17778      0.731987 -0.610403 -0.665649 -1.224990   -0.321645   -0.478556
# 17779      1.129733 -0.610350 -0.774395  0.455355   -0.303466   -0.945246
# 17780      1.278888 -0.539211 -0.711605  0.455045   -0.240252   -0.910471
# 17781      0.508255 -0.351503 -0.787209  0.168008   -0.201685   -1.042930
#
#        XLarge Bags      type       Day     Month      Year
# 0        -0.675702 -1.026443  1.289235  1.641434 -1.214908
# 1        -0.675702 -1.026443  0.491750  1.641434 -1.214908
# 2        -0.675702 -1.026443 -0.305734  1.641434 -1.214908
# 3        -0.675702 -1.026443 -1.103219  1.641434 -1.214908
# 4        -0.675702 -1.026443  1.517088  1.358706 -1.214908
# ...            ...       ...       ...       ...       ...
# 17777    -0.675702  0.974238 -1.331072 -1.185845  1.979143
# 17778    -0.675702  0.974238  1.403161 -1.468572  1.979143
# 17779    -0.675702  0.974238  0.605677 -1.468572  1.979143
# 17780    -0.675702  0.974238 -0.191808 -1.468572  1.979143
# 17781    -0.675702  0.974238 -0.989293 -1.468572  1.979143
#
# [17782 rows x 11 columns]

# %% [markdown]
# ### Modelling

# %%
#importing necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    RF = RandomForestClassifier()
    RF.fit(x_train,y_train)
    pred=RF.predict(x_test)
    acc=accuracy_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRS = i
print("Best Accuracy is ",maxAccu," At random state ",maxRS)
# Out:
# Best Accuracy is  0.9237113402061856  At random state  181

# %% [markdown]
# random state 181

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=maxRS)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (12447, 11)
# (5335, 11)
# (12447,)
# (5335,)

# %% [markdown]
# ### Finding the best Model

# %%
# Importing necessary Libraries

from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier

from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# #### 1. Decision Tree Classifier

# %%
print('DTC for Gini')
DTC1=DecisionTreeClassifier(criterion='gini')
DTC1.fit(x_train,y_train)
predDTC1=DTC1.predict(x_test)
print(accuracy_score(y_test,predDTC1))
print(confusion_matrix(y_test,predDTC1))
print(classification_report(y_test,predDTC1))
print("Training accuracy::",DTC1.score(x_train,y_train))
print("Test accuracy::",DTC1.score(x_test,y_test))
print('\n')

print('DTC for Entropy')
DTC2=DecisionTreeClassifier(criterion='entropy')
DTC2.fit(x_train,y_train)
predDTC2=DTC2.predict(x_test)
print(accuracy_score(y_test,predDTC2))
print(confusion_matrix(y_test,predDTC2))
print(classification_report(y_test,predDTC2))
print("Training accuracy::",DTC2.score(x_train,y_train))
print("Test accuracy::",DTC2.score(x_test,y_test))
# Out:
# DTC for Gini
# 0.818369259606373
# [[1009   63   70   52   50]
#  [  63  886   51   50   29]
#  [  67   52  895   43   68]
#  [  52   52   28  938   24]
#  [  44   27   61   23  638]]
#               precision    recall  f1-score   support
#
#            1       0.82      0.81      0.81      1244
#            2       0.82      0.82      0.82      1079
#            3       0.81      0.80      0.80      1125
#            4       0.85      0.86      0.85      1094
#            5       0.79      0.80      0.80       793
#
#     accuracy                           0.82      5335
#    macro avg       0.82      0.82      0.82      5335
# weighted avg       0.82      0.82      0.82      5335
#
# Training accuracy:: 1.0
# Test accuracy:: 0.818369259606373
#
#
# DTC for Entropy
# 0.8314901593252109
# [[1036   57   55   51   45]
#  [  55  884   45   56   39]
#  [  65   55  904   32   69]
#  [  31   36   32  976   19]
#  [  41   32   64   20  636]]
#               precision    recall  f1-score   support
#
#            1       0.84      0.83      0.84      1244
#            2       0.83      0.82      0.83      1079
#            3       0.82      0.80      0.81      1125
#            4       0.86      0.89      0.88      1094
#            5       0.79      0.80      0.79       793
#
#     accuracy                           0.83      5335
#    macro avg       0.83      0.83      0.83      5335
# weighted avg       0.83      0.83      0.83      5335
#
# Training accuracy:: 1.0
# Test accuracy:: 0.8314901593252109

# %% [markdown]
# DTC is working better with Entropy criterion

# %%
DTC=DecisionTreeClassifier(criterion='entropy')
DTC.fit(x_train,y_train)
predDTC=DTC.predict(x_test)
print(accuracy_score(y_test,predDTC))
print(confusion_matrix(y_test,predDTC))
print(classification_report(y_test,predDTC))
print("Training accuracy::",DTC.score(x_train,y_train))
print("Test accuracy::",DTC.score(x_test,y_test))
# Out:
# 0.8221180880974696
# [[1027   56   67   50   44]
#  [  63  872   52   55   37]
#  [  64   51  905   35   70]
#  [  41   40   28  957   28]
#  [  50   28   69   21  625]]
#               precision    recall  f1-score   support
#
#            1       0.82      0.83      0.83      1244
#            2       0.83      0.81      0.82      1079
#            3       0.81      0.80      0.81      1125
#            4       0.86      0.87      0.87      1094
#            5       0.78      0.79      0.78       793
#
#     accuracy                           0.82      5335
#    macro avg       0.82      0.82      0.82      5335
# weighted avg       0.82      0.82      0.82      5335
#
# Training accuracy:: 1.0
# Test accuracy:: 0.8221180880974696

# %% [markdown]
# #### 2. KNeighbors Classifier

# %%
KNN=KNeighborsClassifier()
KNN.fit(x_train,y_train)
predKNN=KNN.predict(x_test)
print(accuracy_score(y_test,predKNN))
print(confusion_matrix(y_test,predKNN))
print(classification_report(y_test,predKNN))
print("Training accuracy::",KNN.score(x_train,y_train))
print("Test accuracy::",KNN.score(x_test,y_test))
# Out:
# 0.707029053420806
# [[902 108  58 107  69]
#  [159 729  88  79  24]
#  [129 105 809  36  46]
#  [ 87  71  57 860  19]
#  [ 86  48 134  53 472]]
#               precision    recall  f1-score   support
#
#            1       0.66      0.73      0.69      1244
#            2       0.69      0.68      0.68      1079
#            3       0.71      0.72      0.71      1125
#            4       0.76      0.79      0.77      1094
#            5       0.75      0.60      0.66       793
#
#     accuracy                           0.71      5335
#    macro avg       0.71      0.70      0.70      5335
# weighted avg       0.71      0.71      0.71      5335
#
# Training accuracy:: 0.8275086366192657
# Test accuracy:: 0.707029053420806

# %% [markdown]
# #### 3. Support Vector Classifier

# %%
print('SV for rbf')
SV1=SVC(kernel='rbf')
SV1.fit(x_train,y_train)
predSV1=SV1.predict(x_test)
print(accuracy_score(y_test,predSV1))
print(confusion_matrix(y_test,predSV1))
print(classification_report(y_test,predSV1))
print("Training accuracy::",SV1.score(x_train,y_train))
print("Test accuracy::",SV1.score(x_test,y_test))
print('\n')

print('SV for poly')
SV2=SVC(kernel='poly')
SV2.fit(x_train,y_train)
predSV2=SV2.predict(x_test)
print(accuracy_score(y_test,predSV2))
print(confusion_matrix(y_test,predSV2))
print(classification_report(y_test,predSV2))
print("Training accuracy::",SV2.score(x_train,y_train))
print("Test accuracy::",SV2.score(x_test,y_test))
print('\n')

print('SV for linear')
SV3=SVC(kernel='linear')
SV3.fit(x_train,y_train)
predSV3=SV3.predict(x_test)
print(accuracy_score(y_test,predSV3))
print(confusion_matrix(y_test,predSV3))
print(classification_report(y_test,predSV3))
print("Training accuracy::",SV3.score(x_train,y_train))
print("Test accuracy::",SV3.score(x_test,y_test))
# Out:
# SV for rbf
# 0.6348641049671977
# [[768 161 108 161  46]
#  [183 732  64  82  18]
#  [204 166 668  68  19]
#  [104  94  52 830  14]
#  [100  95 156  53 389]]
#               precision    recall  f1-score   support
#
#            1       0.57      0.62      0.59      1244
#            2       0.59      0.68      0.63      1079
#            3       0.64      0.59      0.61      1125
#            4       0.70      0.76      0.73      1094
#            5       0.80      0.49      0.61       793
#
#     accuracy                           0.63      5335
#    macro avg       0.66      0.63      0.63      5335
# weighted avg       0.65      0.63      0.63      5335
#
# Training accuracy:: 0.6498754720012855
# Test accuracy:: 0.6348641049671977
#
#
# SV for poly
# 0.5638238050609184
# [[766 146 100 198  34]
#  [298 596  59  94  32]
#  [301 109 606  67  42]
#  [188 100  46 742  18]
#  [183  78 168  66 298]]
#               precision    recall  f1-score   support
#
#            1       0.44      0.62      0.51      1244
#            2       0.58      0.55      0.57      1079
#            3       0.62      0.54      0.58      1125
#            4       0.64      0.68      0.66      1094
#            5       0.70      0.38      0.49       793
#
#     accuracy                           0.56      5335
#    macro avg       0.60      0.55      0.56      5335
# weighted avg       0.59      0.56      0.56      5335
#
# Training accuracy:: 0.5756407166385474
# Test accuracy:: 0.5638238050609184
#
#
# SV for linear
# 0.39268978444236174
# [[446 217 158 370  53]
#  [286 314 205 203  71]
#  [256 201 426 180  62]
#  [176 175  97 642   4]
#  [121 136 153 116 267]]
#               precision    recall  f1-score   support
#
#            1       0.35      0.36      0.35      1244
#            2       0.30      0.29      0.30      1079
#            3       0.41      0.38      0.39      1125
#            4       0.42      0.59      0.49      1094
#            5       0.58      0.34      0.43       793
#
#     accuracy                           0.39      5335
#    macro avg       0.41      0.39      0.39      5335
# weighted avg       0.40      0.39      0.39      5335
#
# Training accuracy:: 0.3908572346750221
# Test accuracy:: 0.39268978444236174

# %% [markdown]
# for SVC rbf is working better.

# %%
SV=SVC(kernel='rbf')
SV.fit(x_train,y_train)
predSV=SV.predict(x_test)
print(accuracy_score(y_test,predSV))
print(confusion_matrix(y_test,predSV))
print(classification_report(y_test,predSV))
print("Training accuracy::",SV.score(x_train,y_train))
print("Test accuracy::",SV.score(x_test,y_test))
# Out:
# 0.6348641049671977
# [[768 161 108 161  46]
#  [183 732  64  82  18]
#  [204 166 668  68  19]
#  [104  94  52 830  14]
#  [100  95 156  53 389]]
#               precision    recall  f1-score   support
#
#            1       0.57      0.62      0.59      1244
#            2       0.59      0.68      0.63      1079
#            3       0.64      0.59      0.61      1125
#            4       0.70      0.76      0.73      1094
#            5       0.80      0.49      0.61       793
#
#     accuracy                           0.63      5335
#    macro avg       0.66      0.63      0.63      5335
# weighted avg       0.65      0.63      0.63      5335
#
# Training accuracy:: 0.6498754720012855
# Test accuracy:: 0.6348641049671977

# %% [markdown]
# #### 4. Random Forest Classifier

# %%
RF = RandomForestClassifier()
RF.fit(x_train,y_train)
predRF=RF.predict(x_test)
print(accuracy_score(y_test,predRF))
print(confusion_matrix(y_test,predRF))
print(classification_report(y_test,predRF))
print("Training accuracy::",RF.score(x_train,y_train))
print("Test accuracy::",RF.score(x_test,y_test))
# Out:
# 0.9212746016869728
# [[1158   20   28   20   18]
#  [  28 1005   18   23    5]
#  [  27   29 1016   22   31]
#  [  11   13    8 1052   10]
#  [  21   15   65    8  684]]
#               precision    recall  f1-score   support
#
#            1       0.93      0.93      0.93      1244
#            2       0.93      0.93      0.93      1079
#            3       0.90      0.90      0.90      1125
#            4       0.94      0.96      0.95      1094
#            5       0.91      0.86      0.89       793
#
#     accuracy                           0.92      5335
#    macro avg       0.92      0.92      0.92      5335
# weighted avg       0.92      0.92      0.92      5335
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9212746016869728

# %% [markdown]
# #### 5. Ada Boost Classifier

# %%
ABC = AdaBoostClassifier()
ABC.fit(x_train,y_train)
predABC=ABC.predict(x_test)
print(accuracy_score(y_test,predABC))
print(confusion_matrix(y_test,predABC))
print(classification_report(y_test,predABC))
print("Training accuracy::",ABC.score(x_train,y_train))
print("Test accuracy::",ABC.score(x_test,y_test))
# Out:
# 0.4256794751640112
# [[443 264  77 399  61]
#  [182 464 134 180 119]
#  [172 164 444 208 137]
#  [212  81 101 637  63]
#  [115 172 104 119 283]]
#               precision    recall  f1-score   support
#
#            1       0.39      0.36      0.37      1244
#            2       0.41      0.43      0.42      1079
#            3       0.52      0.39      0.45      1125
#            4       0.41      0.58      0.48      1094
#            5       0.43      0.36      0.39       793
#
#     accuracy                           0.43      5335
#    macro avg       0.43      0.42      0.42      5335
# weighted avg       0.43      0.43      0.42      5335
#
# Training accuracy:: 0.4249216678717763
# Test accuracy:: 0.4256794751640112

# %% [markdown]
# #### 6. Bagging Classifier

# %%
BC = BaggingClassifier()
BC.fit(x_train,y_train)
predBC=BC.predict(x_test)
print(accuracy_score(y_test,predBC))
print(confusion_matrix(y_test,predBC))
print(classification_report(y_test,predBC))
print("Training accuracy::",BC.score(x_train,y_train))
print("Test accuracy::",BC.score(x_test,y_test))
# Out:
# 0.8832239925023431
# [[1119   39   40   26   20]
#  [  47  966   20   29   17]
#  [  43   47  961   29   45]
#  [  25   26   22 1009   12]
#  [  34   20   74    8  657]]
#               precision    recall  f1-score   support
#
#            1       0.88      0.90      0.89      1244
#            2       0.88      0.90      0.89      1079
#            3       0.86      0.85      0.86      1125
#            4       0.92      0.92      0.92      1094
#            5       0.87      0.83      0.85       793
#
#     accuracy                           0.88      5335
#    macro avg       0.88      0.88      0.88      5335
# weighted avg       0.88      0.88      0.88      5335
#
# Training accuracy:: 0.995018880051418
# Test accuracy:: 0.8832239925023431

# %% [markdown]
# #### 7. Gradient Boosting Classifier

# %%
GBC = GradientBoostingClassifier()
GBC.fit(x_train,y_train)
predGBC=GBC.predict(x_test)
print(accuracy_score(y_test,predGBC))
print(confusion_matrix(y_test,predGBC))
print(classification_report(y_test,predGBC))
print("Training accuracy::",GBC.score(x_train,y_train))
print("Test accuracy::",GBC.score(x_test,y_test))
# Out:
# 0.7246485473289597
# [[875 118  77 139  35]
#  [107 787  65  86  34]
#  [105 103 805  62  50]
#  [ 70  61  65 860  38]
#  [ 53  56 108  37 539]]
#               precision    recall  f1-score   support
#
#            1       0.72      0.70      0.71      1244
#            2       0.70      0.73      0.71      1079
#            3       0.72      0.72      0.72      1125
#            4       0.73      0.79      0.76      1094
#            5       0.77      0.68      0.72       793
#
#     accuracy                           0.72      5335
#    macro avg       0.73      0.72      0.72      5335
# weighted avg       0.73      0.72      0.72      5335
#
# Training accuracy:: 0.75745159476179
# Test accuracy:: 0.7246485473289597

# %% [markdown]
# #### 8. Extra Trees Classifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
ET = ExtraTreesClassifier()
ET.fit(x_train,y_train)
predET=ET.predict(x_test)
print(accuracy_score(y_test,predET))
print(confusion_matrix(y_test,predET))
print(classification_report(y_test,predET))
print("Training accuracy::",ET.score(x_train,y_train))
print("Test accuracy::",ET.score(x_test,y_test))
# Out:
# 0.9347703842549203
# [[1176   15   22   16   15]
#  [  21 1020   12   21    5]
#  [  21   19 1043   14   28]
#  [   8   13    8 1059    6]
#  [  17   15   61   11  689]]
#               precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95      1244
#            2       0.94      0.95      0.94      1079
#            3       0.91      0.93      0.92      1125
#            4       0.94      0.97      0.96      1094
#            5       0.93      0.87      0.90       793
#
#     accuracy                           0.93      5335
#    macro avg       0.93      0.93      0.93      5335
# weighted avg       0.93      0.93      0.93      5335
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9347703842549203

# %% [markdown]
# ## Cross Validation to avoid overfitting and underfitting

# %%
from sklearn.model_selection import cross_val_score
DTC_score=cross_val_score(DTC,x,y,scoring='accuracy')
print("Decision Tree mean cv = ",np.mean(DTC_score))
# Out:
# Decision Tree mean cv =  0.5186657877352061

# %%
KNN_score=cross_val_score(KNN,x,y,scoring='accuracy')
print("KNeighbor Classifier mean cv = ",np.mean(KNN_score))
# Out:
# KNeighbor Classifier mean cv =  0.4046797407984952

# %%
SV_score=cross_val_score(SV,x,y,scoring='accuracy')
print("Support Vector mean cv = ",np.mean(SV_score))
# Out:
# Support Vector mean cv =  0.45326410035124587

# %%
RF_score=cross_val_score(RF,x,y,scoring='accuracy')
print("Random Forest mean cv = ",np.mean(RF_score))
# Out:
# Random Forest mean cv =  0.6168521298486832

# %%
ABC_score=cross_val_score(ABC,x,y,scoring='accuracy')
print("Ada Boost mean cv = ",np.mean(ABC_score))
# Out:
# Ada Boost mean cv =  0.3416911724943575

# %%
BC_score=cross_val_score(BC,x,y,scoring='accuracy')
print("Bagging Classifier mean cv = ",np.mean(BC_score))
# Out:
# Bagging Classifier mean cv =  0.5700651102896648

# %%
GBC_score=cross_val_score(GBC,x,y,scoring='accuracy')
print("Gradient Boosting mean cv = ",np.mean(GBC_score))
# Out:
# Gradient Boosting mean cv =  0.5317091917488386

# %%
ET_score=cross_val_score(ET,x,y,scoring='accuracy')
print("Extra Trees mean cv = ",np.mean(ET_score))
# Out:
# Extra Trees mean cv =  0.5724820242282759

# %% [markdown]
# From the above Cross validation Technique we can see that the best model is with the highest accuracy and that is Random Forest Classifier

# %% [markdown]
# ## Hyper Parameter Tunning

# %%
from sklearn.model_selection import GridSearchCV
parameters={"n_estimators": [100,50,10,200,300],
            "criterion":["gini","entropy","log_loss"],
            "max_depth":[None,10,30,50,100],
            'max_features': ['sqrt','log2','None'],
            'max_leaf_nodes': [None,50,100,200,500],
            }
GCV=GridSearchCV(RF,parameters,cv=5)
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [None, 10, 30, 50, 100],
#                          'max_features': ['sqrt', 'log2', 'None'],
#                          'max_leaf_nodes': [None, 50, 100, 200, 500],
#                          'n_estimators': [100, 50, 10, 200, 300]})

# %%
best_parameters = GCV.best_params_
print(best_parameters)
best_result=GCV.best_score_
print(best_result)
# Out:
# {'criterion': 'entropy', 'max_depth': 30, 'max_features': 'log2', 'max_leaf_nodes': None, 'n_estimators': 300}
# 0.9097775755492844

# %%
Final_model2=RandomForestClassifier(n_estimators=300, criterion='entropy', max_depth=30, max_features='log2', max_leaf_nodes = None)
Final_model2.fit(x_train,y_train)
pred2= Final_model2.predict(x_test)
acc=accuracy_score(y_test,pred2)
print(acc*100)
# Out:
# 92.78350515463917

# %% [markdown]
# ### Saving the model

# %%
import pickle
filename='Avocado2.pkl'
pickle.dump(Final_model2,open(filename,'wb'))

# %%
model=pickle.load(open("Avocado2.pkl","rb"))
prediction=model.predict(x_test)
prediction
# Out:
# array([1, 4, 1, ..., 4, 5, 1], dtype=int64)

# %%
a=np.array(y_test)
df4=pd.DataFrame()
df4["Predicted"]=prediction
df4["Original"] = a
df4
# Out:
#       Predicted  Original
# 0             1         1
# 1             4         4
# 2             1         1
# 3             3         3
# 4             1         1
# ...         ...       ...
# 5330          5         5
# 5331          2         3
# 5332          4         4
# 5333          5         5
# 5334          1         1
#
# [5335 rows x 2 columns]
